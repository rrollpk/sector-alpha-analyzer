# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
tickers = ["BRK-B", "JPM", "V", "MA", "BAC", "WFC", "GS", "AXP", "MS", "SPGI", "C", "SCHW", "BLK", "PGR", "COF",
"BX", "MMC", "CB", "ICE", "CME", "FI", "KKR", "AJG", "PNC", "MCO", "AON", "COIN", "USB", "PYPL",
"BK", "APO", "TFC", "TRV", "ALL", "AMP", "AFL", "AIG", "MSCI", "MET", "FIS", "PRU", "NDAQ", "HIG",
"ACGL", "MTB", "STT", "WTW", "BRO", "FITB", "RJF", "SYF", "HBAN", "NTRS", "CBOE", "CPAY", "CINF",
"RF", "TROW", "WRB", "CFG", "GPN", "KEY", "FDS", "PFG", "L", "EG", "JKHY", "GL", "AIZ", "ERIE",
"MKTX", "BEN", "IVZ"]

# %%
def CRP(pais): # Defining Country Risk Premium
    return {
        "Abu_Dhabi": 0.0499,
        "Albania": 0.0913,
        "Andorra": 0.0646,
        "Angola": 0.1300,
        "Argentina": 0.2034,
        "Armenia": 0.0913,
        "Aruba": 0.0726,
        "Australia": 0.0433,
        "Austria": 0.0486,
        "Azerbaijan": 0.0767,
        "Bahamas": 0.1034,
        "Bahrain": 0.1167,
        "Bangladesh": 0.1167,
        "Barbados": 0.1300,
        "Belarus": 0.2791,
        "Belgium": 0.0513,
        "Belize": 0.1434,
        "Benin": 0.1034,
        "Bermuda": 0.0546,
        "Bolivia": 0.1768,
        "Bosnia_and_Herzegovina": 0.1300,
        "Botswana": 0.0593,
        "Brazil": 0.0767,
        "Bulgaria": 0.0646,
        "Burkina_Faso": 0.1434,
        "Cambodia": 0.1167,
        "Cameroon": 0.1434,
        "Canada": 0.0433,
        "Cape_Verde": 0.1167,
        "Cayman_Islands": 0.0513,
        "Chile": 0.0546,
        "China": 0.0527,
        "Colombia": 0.0687,
        "Congo_Democratic_Republic_of": 0.1300,
        "Congo_Republic_of": 0.1635,
        "Cook_Islands": 0.1034,
        "Costa_Rica": 0.0913,
        "Côte_d_Ivoire": 0.0835,
        "Croatia": 0.0593,
        "Cuba": 0.2034,
        "Curacao": 0.0726,
        "Cyprus": 0.0593,
        "Czech_Republic": 0.0513,
        "Denmark": 0.0433,
        "Dominican_Republic": 0.0913,
        "Ecuador": 0.1768,
        "Egypt": 0.1434,
        "El_Salvador": 0.1300,
        "Estonia": 0.0527,
        "Ethiopia": 0.1635,
        "Fiji": 0.1034,
        "Finland": 0.0486,
        "France": 0.0513,
        "Gabon": 0.1635,
        "Georgia": 0.0835,
        "Germany": 0.0433,
        "Ghana": 0.1635,
        "Greece": 0.0767,
        "Guatemala": 0.0767,
        "Guernsey": 0.0527,
        "Honduras": 0.1034,
        "Hong_Kong": 0.0513,
        "Hungary": 0.0687,
        "Iceland": 0.0527,
        "India": 0.0726,
        "Indonesia": 0.0687,
        "Iraq": 0.1434,
        "Ireland": 0.0513,
        "Isle_of_Man": 0.0513,
        "Israel": 0.0646,
        "Italy": 0.0726,
        "Jamaica": 0.1034,
        "Japan": 0.0527,
        "Jersey": 0.0499,
        "Jordan": 0.0913,
        "Kazakhstan": 0.0646,
        "Kenya": 0.1434,
        "Korea": 0.0499,
        "Kuwait": 0.0527,
        "Kyrgyzstan": 0.1300,
        "Laos": 0.1768,
        "Latvia": 0.0593,
        "Lebanon": 0.2791,
        "Liechtenstein": 0.0433,
        "Lithuania": 0.0546,
        "Luxembourg": 0.0433,
        "Macao": 0.0513,
        "Macedonia": 0.0913,
        "Malaysia": 0.0593,
        "Maldives": 0.1635,
        "Mali": 0.1635,
        "Malta": 0.0546,
        "Mauritius": 0.0726,
        "Mexico": 0.0687,
        "Moldova": 0.1300,
        "Mongolia": 0.1167,
        "Montenegro": 0.1034,
        "Montserrat": 0.0726,
        "Morocco": 0.0767,
        "Mozambique": 0.1635,
        "Namibia": 0.1034,
        "Nepal": 0.0913,
        "Netherlands": 0.0433,
        "New_Zealand": 0.0433,
        "Nicaragua": 0.1167,
        "Niger": 0.1768,
        "Nigeria": 0.1434,
        "Norway": 0.0433,
        "Oman": 0.0767,
        "Pakistan": 0.1635,
        "Panama": 0.0726,
        "Papua_New_Guinea": 0.1167,
        "Paraguay": 0.0726,
        "Peru": 0.0646,
        "Philippines": 0.0687,
        "Poland": 0.0546,
        "Portugal": 0.0593,
        "Qatar": 0.0499,
        "Ras_Al_Khaimah": 0.0593,
        "Romania": 0.0726,
        "Rwanda": 0.1167,
        "Saudi_Arabia": 0.0513,
        "Senegal": 0.1034,
        "Serbia": 0.0835,
        "Sharjah": 0.0767,
        "Singapore": 0.0433,
        "Slovakia": 0.0593,
        "Slovenia": 0.0593,
        "Solomon_Islands": 0.1434,
        "South_Africa": 0.0835,
        "Spain": 0.0646,
        "Sri_Lanka": 0.2034,
        "St_Maarten": 0.0835,
        "St_Vincent_and_the_Grenadines": 0.1300,
        "Suriname": 0.1434,
        "Swaziland": 0.1167,
        "Sweden": 0.0433,
        "Switzerland": 0.0433,
        "Taiwan": 0.0513,
        "Tajikistan": 0.1300,
        "Tanzania": 0.1034,
        "Thailand": 0.0646,
        "Togo": 0.1300,
        "Trinidad_and_Tobago": 0.0835,
        "Tunisia": 0.1635,
        "Turkey": 0.1034,
        "Turks_and_Caicos_Islands": 0.0646,
        "Uganda": 0.1300,
        "Ukraine": 0.2034,
        "United_Arab_Emirates": 0.0499,
        "United_Kingdom": 0.0513,
        "United_States": 0.0433,
        "Uruguay": 0.0646,
        "Uzbekistan": 0.0913,
        "Venezuela": 0.2791,
        "Vietnam": 0.0835,
        "Zambia": 0.1635
    }.get(pais, 0)

# %%
def risk_free(): # Defining RF de bonos US 10Y
    bond = yf.Ticker("^TNX")  
    return bond.history(period="1d")["Close"].iloc[-1] / 100

# %%
adjusted_risk_free = risk_free() + CRP("Zambia")

# %%
print(adjusted_risk_free)
# Out:
# 0.20693999862670898

# %%
def fundamental_ratios(ticker):
    stock = yf.Ticker(ticker)
    info = stock.info

    ratios = {
        "ticker": ticker,
        "trailingPE": info.get("trailingPE"),
        "forwardPE": info.get("forwardPE"),
        "priceToBook": info.get("priceToBook"),
        "pegRatio": info.get("pegRatio"),
        "enterpriseToEbitda": info.get("enterpriseToEbitda"),
        "debtToEquity": info.get("debtToEquity"),
        "beta": info.get("beta"),
        "marketCap": info.get("marketCap"),
        "sector": info.get("sector")
    }

    return ratios

# %%
for ticker in tickers:
    ratios_tickers = fundamental_ratios(ticker)
    print(ratios_tickers)
# Out:
# {'ticker': 'BRK-B', 'trailingPE': 12.727152, 'forwardPE': 23.78735, 'priceToBook': 0.0010499796, 'pegRatio': None, 'enterpriseToEbitda': -1.879, 'debtToEquity': 19.175, 'beta': 0.843, 'marketCap': 1029942411264, 'sector': 'Financial Services'}
# {'ticker': 'JPM', 'trailingPE': 13.879407, 'forwardPE': 16.905682, 'priceToBook': 2.3734138, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.084, 'marketCap': 786485477376, 'sector': 'Financial Services'}
# {'ticker': 'V', 'trailingPE': 35.73707, 'forwardPE': 28.115417, 'priceToBook': 17.97592, 'pegRatio': None, 'enterpriseToEbitda': 25.647, 'debtToEquity': 54.594, 'beta': 0.943, 'marketCap': 695331127296, 'sector': 'Financial Services'}
# {'ticker': 'MA', 'trailingPE': 39.36634, 'forwardPE': 34.343407, 'priceToBook': 76.7351, 'pegRatio': None, 'enterpriseToEbitda': 28.991, 'debtToEquity': 280.795, 'beta': 1.052, 'marketCap': 510836965376, 'sector': 'Financial Services'}
# {'ticker': 'BAC', 'trailingPE': 14.008956, 'forwardPE': 12.822404, 'priceToBook': 1.2897817, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.307, 'marketCap': 353471135744, 'sector': 'Financial Services'}
# {'ticker': 'WFC', 'trailingPE': 14.695145, 'forwardPE': 14.882515, 'priceToBook': 1.6401687, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.155, 'marketCap': 265882796032, 'sector': 'Financial Services'}
# {'ticker': 'GS', 'trailingPE': 16.197725, 'forwardPE': 16.794033, 'priceToBook': 1.8789945, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 593.344, 'beta': 1.314, 'marketCap': 214162751488, 'sector': 'Financial Services'}
# {'ticker': 'AXP', 'trailingPE': 22.227493, 'forwardPE': 21.066137, 'priceToBook': 7.1559834, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 170.351, 'beta': 1.254, 'marketCap': 223151603712, 'sector': 'Financial Services'}
# {'ticker': 'MS', 'trailingPE': 16.573357, 'forwardPE': 17.806433, 'priceToBook': 2.3375602, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 416.642, 'beta': 1.291, 'marketCap': 226538012672, 'sector': 'Financial Services'}
# {'ticker': 'SPGI', 'trailingPE': 41.552593, 'forwardPE': 31.49197, 'priceToBook': 4.865312, 'pegRatio': None, 'enterpriseToEbitda': 24.724, 'debtToEquity': 31.875, 'beta': 1.195, 'marketCap': 162351857664, 'sector': 'Financial Services'}
# {'ticker': 'C', 'trailingPE': 13.545024, 'forwardPE': 11.924895, 'priceToBook': 0.82521653, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.31, 'marketCap': 160139165696, 'sector': 'Financial Services'}
# {'ticker': 'SCHW', 'trailingPE': 27.978758, 'forwardPE': 24.297342, 'priceToBook': 4.158443, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 110.198, 'beta': 0.933, 'marketCap': 167760658432, 'sector': 'Financial Services'}
# {'ticker': 'BLK', 'trailingPE': 26.324266, 'forwardPE': 22.07271, 'priceToBook': 3.4975555, 'pegRatio': None, 'enterpriseToEbitda': 20.33, 'debtToEquity': 28.41, 'beta': 1.423, 'marketCap': 167904149504, 'sector': 'Financial Services'}
# {'ticker': 'PGR', 'trailingPE': 16.89195, 'forwardPE': 18.140486, 'priceToBook': 5.0665593, 'pegRatio': None, 'enterpriseToEbitda': 13.873, 'debtToEquity': 23.81, 'beta': 0.4, 'marketCap': 146754551808, 'sector': 'Financial Services'}
# {'ticker': 'COF', 'trailingPE': 18.358824, 'forwardPE': 13.95083, 'priceToBook': 1.4253745, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.132, 'marketCap': 139741052928, 'sector': 'Financial Services'}
# {'ticker': 'BX', 'trailingPE': 47.860607, 'forwardPE': 27.09091, 'priceToBook': 15.304264, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 73.101, 'beta': 1.641, 'marketCap': 191617548288, 'sector': 'Financial Services'}
# {'ticker': 'MMC', 'trailingPE': 26.238943, 'forwardPE': 22.649523, 'priceToBook': 7.4816103, 'pegRatio': None, 'enterpriseToEbitda': 17.356, 'debtToEquity': 157.128, 'beta': 0.827, 'marketCap': 105239314432, 'sector': 'Financial Services'}
# {'ticker': 'CB', 'trailingPE': 13.423688, 'forwardPE': 11.808979, 'priceToBook': 1.6999781, 'pegRatio': None, 'enterpriseToEbitda': 12.5, 'debtToEquity': 29.874, 'beta': 0.555, 'marketCap': 111732547584, 'sector': 'Financial Services'}
# {'ticker': 'ICE', 'trailingPE': 37.502815, 'forwardPE': 26.875164, 'priceToBook': 3.7168071, 'pegRatio': None, 'enterpriseToEbitda': 21.578, 'debtToEquity': 73.534, 'beta': 1.129, 'marketCap': 103905804288, 'sector': 'Financial Services'}
# {'ticker': 'CME', 'trailingPE': 27.594976, 'forwardPE': 26.477339, 'priceToBook': 3.653189, 'pegRatio': None, 'enterpriseToEbitda': 22.991, 'debtToEquity': 14.045, 'beta': 0.476, 'marketCap': 98943778816, 'sector': 'Financial Services'}
# {'ticker': 'FI', 'trailingPE': 30.225266, 'forwardPE': 16.788519, 'priceToBook': 3.6747646, 'pegRatio': None, 'enterpriseToEbitda': 13.476, 'debtToEquity': 107.142, 'beta': 0.911, 'marketCap': 94849794048, 'sector': 'Technology'}
# {'ticker': 'KKR', 'trailingPE': 59.935474, 'forwardPE': 22.907791, 'priceToBook': 4.954933, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 74.627, 'beta': 1.884, 'marketCap': 128650723328, 'sector': 'Financial Services'}
# {'ticker': 'AJG', 'trailingPE': 48.507706, 'forwardPE': 27.909132, 'priceToBook': 3.6121693, 'pegRatio': None, 'enterpriseToEbitda': 21.163, 'debtToEquity': 60.048, 'beta': 0.75, 'marketCap': 80609320960, 'sector': 'Financial Services'}
# {'ticker': 'PNC', 'trailingPE': 13.876765, 'forwardPE': 13.090939, 'priceToBook': 1.535333, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.069, 'marketCap': 77726941184, 'sector': 'Financial Services'}
# {'ticker': 'MCO', 'trailingPE': 43.246975, 'forwardPE': 37.5976, 'priceToBook': 24.354424, 'pegRatio': None, 'enterpriseToEbitda': 28.759, 'debtToEquity': 188.388, 'beta': 1.384, 'marketCap': 90112950272, 'sector': 'Financial Services'}
# {'ticker': 'AON', 'trailingPE': 30.835232, 'forwardPE': 20.497717, 'priceToBook': 10.9979725, 'pegRatio': None, 'enterpriseToEbitda': 17.973, 'debtToEquity': 254.468, 'beta': 0.864, 'marketCap': 76972957696, 'sector': 'Financial Services'}
# {'ticker': 'COIN', 'trailingPE': 68.52163, 'forwardPE': 102.11067, 'priceToBook': 8.865584, 'pegRatio': None, 'enterpriseToEbitda': 108.587, 'debtToEquity': 43.892, 'beta': 3.62, 'marketCap': 92848906240, 'sector': 'Financial Services'}
# {'ticker': 'USB', 'trailingPE': 11.669555, 'forwardPE': 10.887991, 'priceToBook': 1.3804058, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.017, 'marketCap': 73453322240, 'sector': 'Financial Services'}
# {'ticker': 'PYPL', 'trailingPE': 16.788698, 'forwardPE': 15.278058, 'priceToBook': 3.6112578, 'pegRatio': None, 'enterpriseToEbitda': 11.683, 'debtToEquity': 66.041, 'beta': 1.449, 'marketCap': 72657649664, 'sector': 'Financial Services'}
# {'ticker': 'BK', 'trailingPE': 15.179445, 'forwardPE': 14.249618, 'priceToBook': 1.76171, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.075, 'marketCap': 66571132928, 'sector': 'Financial Services'}
# {'ticker': 'APO', 'trailingPE': 25.507172, 'forwardPE': 17.23539, 'priceToBook': 5.0291133, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 90.49, 'beta': 1.571, 'marketCap': 83527335936, 'sector': 'Financial Services'}
# {'ticker': 'TFC', 'trailingPE': None, 'forwardPE': 11.398734, 'priceToBook': 1.0039915, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.815, 'marketCap': 58962038784, 'sector': 'Financial Services'}
# {'ticker': 'TRV', 'trailingPE': 13.887734, 'forwardPE': 11.999002, 'priceToBook': 2.0495207, 'pegRatio': None, 'enterpriseToEbitda': 9.961, 'debtToEquity': 28.495, 'beta': 0.537, 'marketCap': 57770291200, 'sector': 'Financial Services'}
# {'ticker': 'ALL', 'trailingPE': 13.209699, 'forwardPE': 10.1623745, 'priceToBook': 2.5555334, 'pegRatio': None, 'enterpriseToEbitda': 9.272, 'debtToEquity': 36.672, 'beta': 0.345, 'marketCap': 51213152256, 'sector': 'Financial Services'}
# {'ticker': 'AMP', 'trailingPE': 18.281687, 'forwardPE': 13.927776, 'priceToBook': 9.473194, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 74.235, 'beta': 1.227, 'marketCap': 51232673792, 'sector': 'Financial Services'}
# {'ticker': 'AFL', 'trailingPE': 15.81182, 'forwardPE': 14.179916, 'priceToBook': 2.0941298, 'pegRatio': None, 'enterpriseToEbitda': 13.108, 'debtToEquity': 42.513, 'beta': 0.807, 'marketCap': 54967373824, 'sector': 'Financial Services'}
# {'ticker': 'AIG', 'trailingPE': 20.251219, 'forwardPE': 12.374068, 'priceToBook': 1.1631131, 'pegRatio': None, 'enterpriseToEbitda': 5.978, 'debtToEquity': 21.112, 'beta': 0.658, 'marketCap': 47852679168, 'sector': 'Financial Services'}
# {'ticker': 'MSCI', 'trailingPE': 40.131542, 'forwardPE': 34.196594, 'priceToBook': -47.175358, 'pegRatio': None, 'enterpriseToEbitda': 28.942, 'debtToEquity': None, 'beta': 1.326, 'marketCap': 45085151232, 'sector': 'Financial Services'}
# {'ticker': 'MET', 'trailingPE': 12.79085, 'forwardPE': 8.078431, 'priceToBook': 1.9170299, 'pegRatio': None, 'enterpriseToEbitda': 9.546, 'debtToEquity': 172.754, 'beta': 0.839, 'marketCap': 52549206016, 'sector': 'Financial Services'}
# {'ticker': 'FIS', 'trailingPE': 50.764328, 'forwardPE': 13.957968, 'priceToBook': 2.7829182, 'pegRatio': None, 'enterpriseToEbitda': 20.014, 'debtToEquity': 80.216, 'beta': 1.077, 'marketCap': 41873981440, 'sector': 'Technology'}
# {'ticker': 'PRU', 'trailingPE': 16.787066, 'forwardPE': 7.2450647, 'priceToBook': 1.2608098, 'pegRatio': None, 'enterpriseToEbitda': 17.729, 'debtToEquity': 148.073, 'beta': 1.047, 'marketCap': 37676965888, 'sector': 'Financial Services'}
# {'ticker': 'NDAQ', 'trailingPE': 40.452488, 'forwardPE': 28.471336, 'priceToBook': 4.4440026, 'pegRatio': None, 'enterpriseToEbitda': 22.082, 'debtToEquity': 84.587, 'beta': 1.013, 'marketCap': 51326504960, 'sector': 'Financial Services'}
# {'ticker': 'HIG', 'trailingPE': 12.125624, 'forwardPE': 10.475452, 'priceToBook': 2.1001918, 'pegRatio': None, 'enterpriseToEbitda': 8.965, 'debtToEquity': 25.92, 'beta': 0.706, 'marketCap': 34552606720, 'sector': 'Financial Services'}
# {'ticker': 'ACGL', 'trailingPE': 9.042051, 'forwardPE': 9.752213, 'priceToBook': 1.5919968, 'pegRatio': None, 'enterpriseToEbitda': 7.576, 'debtToEquity': 12.662, 'beta': 0.516, 'marketCap': 33038403584, 'sector': 'Financial Services'}
# {'ticker': 'MTB', 'trailingPE': 13.325971, 'forwardPE': 12.229115, 'priceToBook': 1.2166935, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.61, 'marketCap': 31957129216, 'sector': 'Financial Services'}
# {'ticker': 'STT', 'trailingPE': 12.277026, 'forwardPE': 11.672377, 'priceToBook': 1.3604542, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.463, 'marketCap': 31090542592, 'sector': 'Financial Services'}
# {'ticker': 'WTW', 'trailingPE': None, 'forwardPE': 16.993643, 'priceToBook': 3.7500155, 'pegRatio': None, 'enterpriseToEbitda': 13.639, 'debtToEquity': 72.169, 'beta': 0.706, 'marketCap': 30480136192, 'sector': 'Financial Services'}
# {'ticker': 'BRO', 'trailingPE': 29.969358, 'forwardPE': 26.305622, 'priceToBook': 4.526865, 'pegRatio': None, 'enterpriseToEbitda': 21.095, 'debtToEquity': 59.026, 'beta': 0.839, 'marketCap': 35485007872, 'sector': 'Financial Services'}
# {'ticker': 'FITB', 'trailingPE': 13.782539, 'forwardPE': 11.894521, 'priceToBook': 1.5841422, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.918, 'marketCap': 28979165184, 'sector': 'Financial Services'}
# {'ticker': 'RJF', 'trailingPE': 15.259152, 'forwardPE': 14.218132, 'priceToBook': 2.6519437, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 36.485, 'beta': 1.043, 'marketCap': 31955976192, 'sector': 'Financial Services'}
# {'ticker': 'SYF', 'trailingPE': 9.584931, 'forwardPE': 10.814529, 'priceToBook': 1.7336042, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.428, 'marketCap': 26634569728, 'sector': 'Financial Services'}
# {'ticker': 'HBAN', 'trailingPE': 13.357693, 'forwardPE': 12.958955, 'priceToBook': 1.3715346, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.945, 'marketCap': 25297504256, 'sector': 'Financial Services'}
# {'ticker': 'NTRS', 'trailingPE': 11.886088, 'forwardPE': 16.662304, 'priceToBook': 2.0648155, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.235, 'marketCap': 24764815360, 'sector': 'Financial Services'}
# {'ticker': 'CBOE', 'trailingPE': 30.393183, 'forwardPE': 25.261436, 'priceToBook': 5.4555717, 'pegRatio': None, 'enterpriseToEbitda': 18.159, 'debtToEquity': 36.019, 'beta': 0.428, 'marketCap': 24282943488, 'sector': 'Financial Services'}
# {'ticker': 'CPAY', 'trailingPE': 23.256842, 'forwardPE': 14.941839, 'priceToBook': 6.7620897, 'pegRatio': None, 'enterpriseToEbitda': 14.035, 'debtToEquity': 235.922, 'beta': 0.964, 'marketCap': 23362217984, 'sector': 'Technology'}
# {'ticker': 'CINF', 'trailingPE': 15.919028, 'forwardPE': 19.915073, 'priceToBook': 1.663239, 'pegRatio': None, 'enterpriseToEbitda': 11.68, 'debtToEquity': 6.4, 'beta': 0.786, 'marketCap': 22816866304, 'sector': 'Financial Services'}
# {'ticker': 'RF', 'trailingPE': 11.891305, 'forwardPE': 10.891593, 'priceToBook': 1.3160286, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.978, 'marketCap': 22127161344, 'sector': 'Financial Services'}
# {'ticker': 'TROW', 'trailingPE': 11.467649, 'forwardPE': 10.805347, 'priceToBook': 2.1485689, 'pegRatio': None, 'enterpriseToEbitda': 7.087, 'debtToEquity': 4.48, 'beta': 1.513, 'marketCap': 22258526208, 'sector': 'Financial Services'}
# {'ticker': 'WRB', 'trailingPE': 16.222738, 'forwardPE': 16.073563, 'priceToBook': 2.9753191, 'pegRatio': None, 'enterpriseToEbitda': 11.832, 'debtToEquity': 34.344, 'beta': 0.432, 'marketCap': 26524571648, 'sector': 'Financial Services'}
# {'ticker': 'CFG', 'trailingPE': 15.003174, 'forwardPE': 12.211886, 'priceToBook': 0.9090734, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.074, 'marketCap': 20494249984, 'sector': 'Financial Services'}
# {'ticker': 'GPN', 'trailingPE': 13.021116, 'forwardPE': 6.2867575, 'priceToBook': 0.8874509, 'pegRatio': None, 'enterpriseToEbitda': 7.763, 'debtToEquity': 73.574, 'beta': 0.936, 'marketCap': 19625144320, 'sector': 'Industrials'}
# {'ticker': 'KEY', 'trailingPE': None, 'forwardPE': 11.798078, 'priceToBook': 1.2401456, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.074, 'marketCap': 20170776576, 'sector': 'Financial Services'}
# {'ticker': 'FDS', 'trailingPE': 32.209805, 'forwardPE': 23.915953, 'priceToBook': 7.8578463, 'pegRatio': None, 'enterpriseToEbitda': 21.362, 'debtToEquity': 75.191, 'beta': 0.852, 'marketCap': 16890187776, 'sector': 'Financial Services'}
# {'ticker': 'PFG', 'trailingPE': 17.29122, 'forwardPE': 9.567536, 'priceToBook': 1.6195672, 'pegRatio': None, 'enterpriseToEbitda': 10.821, 'debtToEquity': 39.589, 'beta': 0.996, 'marketCap': 18103422976, 'sector': 'Financial Services'}
# {'ticker': 'L', 'trailingPE': 14.909836, 'forwardPE': 31.362066, 'priceToBook': 1.1128377, 'pegRatio': None, 'enterpriseToEbitda': 8.446, 'debtToEquity': 49.606, 'beta': 0.706, 'marketCap': 19071940608, 'sector': 'Financial Services'}
# {'ticker': 'EG', 'trailingPE': 17.153284, 'forwardPE': 5.109598, 'priceToBook': 1.0208262, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 25.368, 'beta': 0.519, 'marketCap': 14446273536, 'sector': 'Financial Services'}
# {'ticker': 'JKHY', 'trailingPE': 30.490646, 'forwardPE': 28.36788, 'priceToBook': 6.4105916, 'pegRatio': None, 'enterpriseToEbitda': 22.001, 'debtToEquity': 10.972, 'beta': 0.732, 'marketCap': 13054817280, 'sector': 'Technology'}
# {'ticker': 'GL', 'trailingPE': 9.57899, 'forwardPE': 8.681181, 'priceToBook': 1.7978265, 'pegRatio': None, 'enterpriseToEbitda': 8.608, 'debtToEquity': 58.407, 'beta': 0.564, 'marketCap': 9709520896, 'sector': 'Financial Services'}
# {'ticker': 'AIZ', 'trailingPE': 14.810452, 'forwardPE': 10.595424, 'priceToBook': 1.8434337, 'pegRatio': None, 'enterpriseToEbitda': 8.729, 'debtToEquity': 39.809, 'beta': 0.603, 'marketCap': 9626845184, 'sector': 'Financial Services'}
# {'ticker': 'ERIE', 'trailingPE': 29.181545, 'forwardPE': 25.610075, 'priceToBook': 8.680063, 'pegRatio': None, 'enterpriseToEbitda': 22.936, 'debtToEquity': 0.615, 'beta': 0.357, 'marketCap': 17944586240, 'sector': 'Financial Services'}
# {'ticker': 'MKTX', 'trailingPE': 37.776432, 'forwardPE': 26.484814, 'priceToBook': 6.07836, 'pegRatio': None, 'enterpriseToEbitda': 19.142, 'debtToEquity': 5.259, 'beta': 0.842, 'marketCap': 8174245376, 'sector': 'Financial Services'}
# {'ticker': 'BEN', 'trailingPE': 35.927536, 'forwardPE': 9.534616, 'priceToBook': 1.0549835, 'pegRatio': None, 'enterpriseToEbitda': 9.761, 'debtToEquity': 24.117, 'beta': 1.458, 'marketCap': 13027665920, 'sector': 'Financial Services'}
# {'ticker': 'IVZ', 'trailingPE': 13.524, 'forwardPE': 8.944445, 'priceToBook': 0.70788497, 'pegRatio': None, 'enterpriseToEbitda': 9.667, 'debtToEquity': 6.111, 'beta': 1.435, 'marketCap': 7565934592, 'sector': 'Financial Services'}

# %%
def calculate_book(ticker):
    stock = yf.Ticker(ticker)
    info = stock.info

    book_value = info.get("bookValue")

    # Ajuste especial para BRK.B
    if ticker == "BRK-B" and book_value and book_value > 10000:
        book_value = book_value / 1500  # Aproximado por la proporción entre clase A y B

    return book_value

# %%
def get_sector_pb_average(tickers):
    pb_values = []

    for ticker in tickers:
        try:
            info = yf.Ticker(ticker).info
            pb = info.get("priceToBook")
            if pb is not None and pb > 0:
                pb_values.append(pb)
        except Exception as e:
            continue  # Si falla, pasa al siguiente

    if pb_values:
        avg_pb = np.mean(pb_values)
        return round(avg_pb, 2), pb_values
    else:
        return None, []

# %%
avg_pb, pb_list = get_sector_pb_average(tickers)

# Iterar sobre cada empresa y calcular su fair value
for ticker in tickers:
    BVPS = calculate_book(ticker)
    if BVPS is not None and avg_pb is not None:
        fair_value = BVPS * avg_pb
        print(f"{ticker} - Fair Value: {fair_value:.2f}")
# Out:
# BRK-B - Fair Value: 1461.79
# JPM - Fair Value: 574.73
# V - Fair Value: 95.44
# MA - Fair Value: 35.34
# BAC - Fair Value: 175.38
# WFC - Fair Value: 240.11
# GS - Fair Value: 1790.41
# AXP - Fair Value: 214.54
# MS - Fair Value: 291.16
# SPGI - Fair Value: 524.45
# C - Fair Value: 500.80
# SCHW - Fair Value: 107.02
# BLK - Fair Value: 1493.55
# PGR - Fair Value: 238.16
# COF - Fair Value: 738.77
# BX - Fair Value: 49.74
# MMC - Fair Value: 137.60
# CB - Fair Value: 790.52
# ICE - Fair Value: 234.90
# CME - Fair Value: 362.27
# FI - Fair Value: 224.39
# KKR - Fair Value: 135.26
# AJG - Fair Value: 420.08
# PNC - Fair Value: 616.87
# MCO - Fair Value: 99.11
# AON - Fair Value: 156.22
# COIN - Fair Value: 198.19
# USB - Fair Value: 164.62
# PYPL - Fair Value: 99.72
# BK - Fair Value: 254.58
# APO - Fair Value: 140.08
# TFC - Fair Value: 216.16
# TRV - Fair Value: 599.65
# ALL - Fair Value: 364.75
# AMP - Fair Value: 273.75
# AFL - Fair Value: 234.01
# AIG - Fair Value: 344.08
# MSCI - Fair Value: -59.54
# MET - Fair Value: 196.82
# FIS - Fair Value: 138.04
# PRU - Fair Value: 406.88
# NDAQ - Fair Value: 96.96
# HIG - Fair Value: 279.12
# ACGL - Fair Value: 266.92
# MTB - Fair Value: 788.71
# STT - Fair Value: 386.25
# WTW - Fair Value: 395.13
# BRO - Fair Value: 114.56
# FITB - Fair Value: 132.10
# RJF - Fair Value: 287.88
# SYF - Fair Value: 194.54
# HBAN - Fair Value: 61.03
# NTRS - Fair Value: 297.16
# CBOE - Fair Value: 204.88
# CPAY - Fair Value: 236.23
# CINF - Fair Value: 423.04
# RF - Fair Value: 90.15
# TROW - Fair Value: 226.65
# WRB - Fair Value: 113.27
# CFG - Fair Value: 250.58
# GPN - Fair Value: 437.06
# KEY - Fair Value: 71.53
# FDS - Fair Value: 274.04
# PFG - Fair Value: 240.32
# L - Fair Value: 393.93
# EG - Fair Value: 1603.64
# JKHY - Fair Value: 134.80
# GL - Fair Value: 315.37
# AIZ - Fair Value: 496.45
# ERIE - Fair Value: 190.56
# MKTX - Fair Value: 172.85
# BEN - Fair Value: 113.26
# IVZ - Fair Value: 115.11

# %%
print("P/B promedio del sector:", avg_pb) #Corregir esto, porque es un dato anómalo
# Out:
# P/B promedio del sector: 4.82
