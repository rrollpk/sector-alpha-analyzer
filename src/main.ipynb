# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
tickers = ["BRK-B", "JPM", "V", "MA", "BAC", "WFC", "GS", "AXP", "MS", "SPGI", "C", "SCHW", "BLK", "PGR", "COF",
"BX", "MMC", "CB", "ICE", "CME", "FI", "KKR", "AJG", "PNC", "MCO", "AON", "COIN", "USB", "PYPL",
"BK", "APO", "TFC", "TRV", "ALL", "AMP", "AFL", "AIG", "MSCI", "MET", "FIS", "PRU", "NDAQ", "HIG",
"ACGL", "MTB", "STT", "WTW", "BRO", "FITB", "RJF", "SYF", "HBAN", "NTRS", "CBOE", "CPAY", "CINF",
"RF", "TROW", "WRB", "CFG", "GPN", "KEY", "FDS", "PFG", "L", "EG", "JKHY", "GL", "AIZ", "ERIE",
"MKTX", "BEN", "IVZ"]

# %%
def CRP(pais): # Defining Country Risk Premium
    return {
        "Abu_Dhabi": 0.0499,
        "Albania": 0.0913,
        "Andorra": 0.0646,
        "Angola": 0.1300,
        "Argentina": 0.2034,
        "Armenia": 0.0913,
        "Aruba": 0.0726,
        "Australia": 0.0433,
        "Austria": 0.0486,
        "Azerbaijan": 0.0767,
        "Bahamas": 0.1034,
        "Bahrain": 0.1167,
        "Bangladesh": 0.1167,
        "Barbados": 0.1300,
        "Belarus": 0.2791,
        "Belgium": 0.0513,
        "Belize": 0.1434,
        "Benin": 0.1034,
        "Bermuda": 0.0546,
        "Bolivia": 0.1768,
        "Bosnia_and_Herzegovina": 0.1300,
        "Botswana": 0.0593,
        "Brazil": 0.0767,
        "Bulgaria": 0.0646,
        "Burkina_Faso": 0.1434,
        "Cambodia": 0.1167,
        "Cameroon": 0.1434,
        "Canada": 0.0433,
        "Cape_Verde": 0.1167,
        "Cayman_Islands": 0.0513,
        "Chile": 0.0546,
        "China": 0.0527,
        "Colombia": 0.0687,
        "Congo_Democratic_Republic_of": 0.1300,
        "Congo_Republic_of": 0.1635,
        "Cook_Islands": 0.1034,
        "Costa_Rica": 0.0913,
        "Côte_d_Ivoire": 0.0835,
        "Croatia": 0.0593,
        "Cuba": 0.2034,
        "Curacao": 0.0726,
        "Cyprus": 0.0593,
        "Czech_Republic": 0.0513,
        "Denmark": 0.0433,
        "Dominican_Republic": 0.0913,
        "Ecuador": 0.1768,
        "Egypt": 0.1434,
        "El_Salvador": 0.1300,
        "Estonia": 0.0527,
        "Ethiopia": 0.1635,
        "Fiji": 0.1034,
        "Finland": 0.0486,
        "France": 0.0513,
        "Gabon": 0.1635,
        "Georgia": 0.0835,
        "Germany": 0.0433,
        "Ghana": 0.1635,
        "Greece": 0.0767,
        "Guatemala": 0.0767,
        "Guernsey": 0.0527,
        "Honduras": 0.1034,
        "Hong_Kong": 0.0513,
        "Hungary": 0.0687,
        "Iceland": 0.0527,
        "India": 0.0726,
        "Indonesia": 0.0687,
        "Iraq": 0.1434,
        "Ireland": 0.0513,
        "Isle_of_Man": 0.0513,
        "Israel": 0.0646,
        "Italy": 0.0726,
        "Jamaica": 0.1034,
        "Japan": 0.0527,
        "Jersey": 0.0499,
        "Jordan": 0.0913,
        "Kazakhstan": 0.0646,
        "Kenya": 0.1434,
        "Korea": 0.0499,
        "Kuwait": 0.0527,
        "Kyrgyzstan": 0.1300,
        "Laos": 0.1768,
        "Latvia": 0.0593,
        "Lebanon": 0.2791,
        "Liechtenstein": 0.0433,
        "Lithuania": 0.0546,
        "Luxembourg": 0.0433,
        "Macao": 0.0513,
        "Macedonia": 0.0913,
        "Malaysia": 0.0593,
        "Maldives": 0.1635,
        "Mali": 0.1635,
        "Malta": 0.0546,
        "Mauritius": 0.0726,
        "Mexico": 0.0687,
        "Moldova": 0.1300,
        "Mongolia": 0.1167,
        "Montenegro": 0.1034,
        "Montserrat": 0.0726,
        "Morocco": 0.0767,
        "Mozambique": 0.1635,
        "Namibia": 0.1034,
        "Nepal": 0.0913,
        "Netherlands": 0.0433,
        "New_Zealand": 0.0433,
        "Nicaragua": 0.1167,
        "Niger": 0.1768,
        "Nigeria": 0.1434,
        "Norway": 0.0433,
        "Oman": 0.0767,
        "Pakistan": 0.1635,
        "Panama": 0.0726,
        "Papua_New_Guinea": 0.1167,
        "Paraguay": 0.0726,
        "Peru": 0.0646,
        "Philippines": 0.0687,
        "Poland": 0.0546,
        "Portugal": 0.0593,
        "Qatar": 0.0499,
        "Ras_Al_Khaimah": 0.0593,
        "Romania": 0.0726,
        "Rwanda": 0.1167,
        "Saudi_Arabia": 0.0513,
        "Senegal": 0.1034,
        "Serbia": 0.0835,
        "Sharjah": 0.0767,
        "Singapore": 0.0433,
        "Slovakia": 0.0593,
        "Slovenia": 0.0593,
        "Solomon_Islands": 0.1434,
        "South_Africa": 0.0835,
        "Spain": 0.0646,
        "Sri_Lanka": 0.2034,
        "St_Maarten": 0.0835,
        "St_Vincent_and_the_Grenadines": 0.1300,
        "Suriname": 0.1434,
        "Swaziland": 0.1167,
        "Sweden": 0.0433,
        "Switzerland": 0.0433,
        "Taiwan": 0.0513,
        "Tajikistan": 0.1300,
        "Tanzania": 0.1034,
        "Thailand": 0.0646,
        "Togo": 0.1300,
        "Trinidad_and_Tobago": 0.0835,
        "Tunisia": 0.1635,
        "Turkey": 0.1034,
        "Turks_and_Caicos_Islands": 0.0646,
        "Uganda": 0.1300,
        "Ukraine": 0.2034,
        "United_Arab_Emirates": 0.0499,
        "United_Kingdom": 0.0513,
        "United_States": 0.0433,
        "Uruguay": 0.0646,
        "Uzbekistan": 0.0913,
        "Venezuela": 0.2791,
        "Vietnam": 0.0835,
        "Zambia": 0.1635
    }.get(pais, 0)

# %%
def risk_free(): # Defining RF de bonos US 10Y
    bond = yf.Ticker("^TNX")  
    return bond.history(period="1d")["Close"].iloc[-1] / 100

# %%
adjusted_risk_free = risk_free() + CRP("Zambia")

# %%
print(adjusted_risk_free)
# Out:
# 0.20692000007629396

# %%
def fundamental_ratios(ticker):
    stock = yf.Ticker(ticker)
    info = stock.info

    ratios = {
        "ticker": ticker,
        "trailingPE": info.get("trailingPE"),
        "forwardPE": info.get("forwardPE"),
        "priceToBook": info.get("priceToBook"),
        "pegRatio": info.get("pegRatio"),
        "enterpriseToEbitda": info.get("enterpriseToEbitda"),
        "debtToEquity": info.get("debtToEquity"),
        "beta": info.get("beta"),
        "marketCap": info.get("marketCap"),
        "sector": info.get("sector")
    }

    return ratios

# %%
for ticker in tickers:
    ratios_tickers = fundamental_ratios(ticker)
    print(ratios_tickers)
# Out:
# {'ticker': 'BRK-B', 'trailingPE': 12.760725, 'forwardPE': 23.8501, 'priceToBook': 0.0010527493, 'pegRatio': None, 'enterpriseToEbitda': -1.879, 'debtToEquity': 19.175, 'beta': 0.843, 'marketCap': 1032659337216, 'sector': 'Financial Services'}
# {'ticker': 'JPM', 'trailingPE': 13.8872, 'forwardPE': 16.915174, 'priceToBook': 2.3747463, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.084, 'marketCap': 786927124480, 'sector': 'Financial Services'}
# {'ticker': 'V', 'trailingPE': 35.919678, 'forwardPE': 28.259085, 'priceToBook': 18.067774, 'pegRatio': None, 'enterpriseToEbitda': 25.647, 'debtToEquity': 54.594, 'beta': 0.943, 'marketCap': 698884161536, 'sector': 'Financial Services'}
# {'ticker': 'MA', 'trailingPE': 39.545834, 'forwardPE': 34.5, 'priceToBook': 77.084984, 'pegRatio': None, 'enterpriseToEbitda': 28.991, 'debtToEquity': 280.795, 'beta': 1.052, 'marketCap': 513166180352, 'sector': 'Financial Services'}
# {'ticker': 'BAC', 'trailingPE': 13.98209, 'forwardPE': 12.797814, 'priceToBook': 1.2873082, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.307, 'marketCap': 352793264128, 'sector': 'Financial Services'}
# {'ticker': 'WFC', 'trailingPE': 14.710432, 'forwardPE': 14.897997, 'priceToBook': 1.641875, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.155, 'marketCap': 266159390720, 'sector': 'Financial Services'}
# {'ticker': 'GS', 'trailingPE': 16.165236, 'forwardPE': 16.760345, 'priceToBook': 1.8752254, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 593.344, 'beta': 1.314, 'marketCap': 213733163008, 'sector': 'Financial Services'}
# {'ticker': 'AXP', 'trailingPE': 22.14585, 'forwardPE': 20.988758, 'priceToBook': 7.1296983, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 170.351, 'beta': 1.254, 'marketCap': 222331928576, 'sector': 'Financial Services'}
# {'ticker': 'MS', 'trailingPE': 16.61385, 'forwardPE': 17.849937, 'priceToBook': 2.3432715, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 416.642, 'beta': 1.291, 'marketCap': 227091496960, 'sector': 'Financial Services'}
# {'ticker': 'SPGI', 'trailingPE': 41.501568, 'forwardPE': 31.453302, 'priceToBook': 4.859338, 'pegRatio': None, 'enterpriseToEbitda': 24.724, 'debtToEquity': 31.875, 'beta': 1.195, 'marketCap': 162152497152, 'sector': 'Financial Services'}
# {'ticker': 'C', 'trailingPE': 13.552923, 'forwardPE': 11.9318495, 'priceToBook': 0.8256978, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.31, 'marketCap': 160232554496, 'sector': 'Financial Services'}
# {'ticker': 'SCHW', 'trailingPE': 27.975758, 'forwardPE': 24.294737, 'priceToBook': 4.1579967, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 110.198, 'beta': 0.933, 'marketCap': 167742668800, 'sector': 'Financial Services'}
# {'ticker': 'BLK', 'trailingPE': 26.445229, 'forwardPE': 22.174135, 'priceToBook': 3.513627, 'pegRatio': None, 'enterpriseToEbitda': 20.33, 'debtToEquity': 28.41, 'beta': 1.423, 'marketCap': 168675688448, 'sector': 'Financial Services'}
# {'ticker': 'PGR', 'trailingPE': 16.89676, 'forwardPE': 18.145653, 'priceToBook': 5.0680027, 'pegRatio': None, 'enterpriseToEbitda': 13.873, 'debtToEquity': 23.81, 'beta': 0.4, 'marketCap': 146796347392, 'sector': 'Financial Services'}
# {'ticker': 'COF', 'trailingPE': 18.32185, 'forwardPE': 13.922733, 'priceToBook': 1.4225037, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.132, 'marketCap': 139459624960, 'sector': 'Financial Services'}
# {'ticker': 'BX', 'trailingPE': 48.084846, 'forwardPE': 27.217838, 'priceToBook': 15.375969, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 73.101, 'beta': 1.641, 'marketCap': 192515325952, 'sector': 'Financial Services'}
# {'ticker': 'MMC', 'trailingPE': 26.31081, 'forwardPE': 22.711557, 'priceToBook': 7.5021014, 'pegRatio': None, 'enterpriseToEbitda': 17.356, 'debtToEquity': 157.128, 'beta': 0.827, 'marketCap': 105527558144, 'sector': 'Financial Services'}
# {'ticker': 'CB', 'trailingPE': 13.480982, 'forwardPE': 11.859382, 'priceToBook': 1.7072338, 'pegRatio': None, 'enterpriseToEbitda': 12.5, 'debtToEquity': 29.874, 'beta': 0.555, 'marketCap': 112209436672, 'sector': 'Financial Services'}
# {'ticker': 'ICE', 'trailingPE': 37.714287, 'forwardPE': 27.026709, 'priceToBook': 3.7377656, 'pegRatio': None, 'enterpriseToEbitda': 21.578, 'debtToEquity': 73.534, 'beta': 1.129, 'marketCap': 104491712512, 'sector': 'Financial Services'}
# {'ticker': 'CME', 'trailingPE': 27.702515, 'forwardPE': 26.580523, 'priceToBook': 3.6674254, 'pegRatio': None, 'enterpriseToEbitda': 22.991, 'debtToEquity': 14.045, 'beta': 0.476, 'marketCap': 99329359872, 'sector': 'Financial Services'}
# {'ticker': 'FI', 'trailingPE': 30.20318, 'forwardPE': 16.77625, 'priceToBook': 3.6720796, 'pegRatio': None, 'enterpriseToEbitda': 13.476, 'debtToEquity': 107.142, 'beta': 0.911, 'marketCap': 94780489728, 'sector': 'Technology'}
# {'ticker': 'KKR', 'trailingPE': 60.00862, 'forwardPE': 22.93575, 'priceToBook': 4.960981, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 74.627, 'beta': 1.884, 'marketCap': 128807731200, 'sector': 'Financial Services'}
# {'ticker': 'AJG', 'trailingPE': 48.574734, 'forwardPE': 27.947695, 'priceToBook': 3.6171606, 'pegRatio': None, 'enterpriseToEbitda': 21.163, 'debtToEquity': 60.048, 'beta': 0.75, 'marketCap': 80720707584, 'sector': 'Financial Services'}
# {'ticker': 'PNC', 'trailingPE': 13.851695, 'forwardPE': 13.067288, 'priceToBook': 1.5325593, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.069, 'marketCap': 77586513920, 'sector': 'Financial Services'}
# {'ticker': 'MCO', 'trailingPE': 43.369602, 'forwardPE': 37.704205, 'priceToBook': 24.42348, 'pegRatio': None, 'enterpriseToEbitda': 28.759, 'debtToEquity': 188.388, 'beta': 1.384, 'marketCap': 90368458752, 'sector': 'Financial Services'}
# {'ticker': 'AON', 'trailingPE': 30.875433, 'forwardPE': 20.52444, 'priceToBook': 11.012311, 'pegRatio': None, 'enterpriseToEbitda': 17.973, 'debtToEquity': 254.468, 'beta': 0.864, 'marketCap': 77073309696, 'sector': 'Financial Services'}
# {'ticker': 'COIN', 'trailingPE': 70.27255, 'forwardPE': 104.719894, 'priceToBook': 9.092125, 'pegRatio': None, 'enterpriseToEbitda': 108.587, 'debtToEquity': 43.892, 'beta': 3.62, 'marketCap': 95221465088, 'sector': 'Financial Services'}
# {'ticker': 'USB', 'trailingPE': 11.707921, 'forwardPE': 10.923787, 'priceToBook': 1.3849442, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.017, 'marketCap': 73694814208, 'sector': 'Financial Services'}
# {'ticker': 'PYPL', 'trailingPE': 16.815731, 'forwardPE': 15.302659, 'priceToBook': 3.6170728, 'pegRatio': None, 'enterpriseToEbitda': 11.683, 'debtToEquity': 66.041, 'beta': 1.449, 'marketCap': 72774647808, 'sector': 'Financial Services'}
# {'ticker': 'BK', 'trailingPE': 15.179445, 'forwardPE': 14.249618, 'priceToBook': 1.76171, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.075, 'marketCap': 66571132928, 'sector': 'Financial Services'}
# {'ticker': 'APO', 'trailingPE': 25.593367, 'forwardPE': 17.293633, 'priceToBook': 5.0461082, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 90.49, 'beta': 1.571, 'marketCap': 83809591296, 'sector': 'Financial Services'}
# {'ticker': 'TFC', 'trailingPE': None, 'forwardPE': 11.432911, 'priceToBook': 1.0070018, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.815, 'marketCap': 59138826240, 'sector': 'Financial Services'}
# {'ticker': 'TRV', 'trailingPE': 13.906318, 'forwardPE': 12.015059, 'priceToBook': 2.0522633, 'pegRatio': None, 'enterpriseToEbitda': 9.961, 'debtToEquity': 28.495, 'beta': 0.537, 'marketCap': 57847595008, 'sector': 'Financial Services'}
# {'ticker': 'ALL', 'trailingPE': 13.257513, 'forwardPE': 10.199159, 'priceToBook': 2.5647836, 'pegRatio': None, 'enterpriseToEbitda': 9.272, 'debtToEquity': 36.672, 'beta': 0.345, 'marketCap': 51398524928, 'sector': 'Financial Services'}
# {'ticker': 'AMP', 'trailingPE': 18.330614, 'forwardPE': 13.965052, 'priceToBook': 9.498548, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 74.235, 'beta': 1.227, 'marketCap': 51369787392, 'sector': 'Financial Services'}
# {'ticker': 'AFL', 'trailingPE': 15.849146, 'forwardPE': 14.213389, 'priceToBook': 2.0990732, 'pegRatio': None, 'enterpriseToEbitda': 13.108, 'debtToEquity': 42.513, 'beta': 0.807, 'marketCap': 55097135104, 'sector': 'Financial Services'}
# {'ticker': 'AIG', 'trailingPE': 20.260977, 'forwardPE': 12.38003, 'priceToBook': 1.1636735, 'pegRatio': None, 'enterpriseToEbitda': 5.978, 'debtToEquity': 21.112, 'beta': 0.658, 'marketCap': 47875731456, 'sector': 'Financial Services'}
# {'ticker': 'MSCI', 'trailingPE': 40.069557, 'forwardPE': 34.143776, 'priceToBook': -47.102493, 'pegRatio': None, 'enterpriseToEbitda': 28.942, 'debtToEquity': None, 'beta': 1.326, 'marketCap': 45015515136, 'sector': 'Financial Services'}
# {'ticker': 'MET', 'trailingPE': 12.784313, 'forwardPE': 8.074304, 'priceToBook': 1.9160503, 'pegRatio': None, 'enterpriseToEbitda': 9.546, 'debtToEquity': 172.754, 'beta': 0.839, 'marketCap': 52522352640, 'sector': 'Financial Services'}
# {'ticker': 'FIS', 'trailingPE': 50.968147, 'forwardPE': 14.014009, 'priceToBook': 2.794092, 'pegRatio': None, 'enterpriseToEbitda': 20.014, 'debtToEquity': 80.216, 'beta': 1.077, 'marketCap': 42042105856, 'sector': 'Technology'}
# {'ticker': 'PRU', 'trailingPE': 16.813879, 'forwardPE': 7.256637, 'priceToBook': 1.2628237, 'pegRatio': None, 'enterpriseToEbitda': 17.729, 'debtToEquity': 148.073, 'beta': 1.047, 'marketCap': 37737148416, 'sector': 'Financial Services'}
# {'ticker': 'NDAQ', 'trailingPE': 40.64706, 'forwardPE': 28.60828, 'priceToBook': 4.4653773, 'pegRatio': None, 'enterpriseToEbitda': 22.082, 'debtToEquity': 84.587, 'beta': 1.013, 'marketCap': 51573379072, 'sector': 'Financial Services'}
# {'ticker': 'HIG', 'trailingPE': 12.150549, 'forwardPE': 10.496985, 'priceToBook': 2.1045089, 'pegRatio': None, 'enterpriseToEbitda': 8.965, 'debtToEquity': 25.92, 'beta': 0.706, 'marketCap': 34623635456, 'sector': 'Financial Services'}
# {'ticker': 'ACGL', 'trailingPE': 9.017436, 'forwardPE': 9.725663, 'priceToBook': 1.5876627, 'pegRatio': None, 'enterpriseToEbitda': 7.576, 'debtToEquity': 12.662, 'beta': 0.516, 'marketCap': 32948459520, 'sector': 'Financial Services'}
# {'ticker': 'MTB', 'trailingPE': 13.412316, 'forwardPE': 12.308353, 'priceToBook': 1.2245771, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.61, 'marketCap': 32164196352, 'sector': 'Financial Services'}
# {'ticker': 'STT', 'trailingPE': 12.319819, 'forwardPE': 11.713062, 'priceToBook': 1.3651962, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.463, 'marketCap': 31198912512, 'sector': 'Financial Services'}
# {'ticker': 'WTW', 'trailingPE': None, 'forwardPE': 17.054174, 'priceToBook': 3.763373, 'pegRatio': None, 'enterpriseToEbitda': 13.639, 'debtToEquity': 72.169, 'beta': 0.706, 'marketCap': 30588704768, 'sector': 'Financial Services'}
# {'ticker': 'BRO', 'trailingPE': 30.119778, 'forwardPE': 26.43765, 'priceToBook': 4.5495853, 'pegRatio': None, 'enterpriseToEbitda': 21.095, 'debtToEquity': 59.026, 'beta': 0.839, 'marketCap': 35663110144, 'sector': 'Financial Services'}
# {'ticker': 'FITB', 'trailingPE': 13.787301, 'forwardPE': 11.89863, 'priceToBook': 1.5846895, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.918, 'marketCap': 28989175808, 'sector': 'Financial Services'}
# {'ticker': 'RJF', 'trailingPE': 15.285164, 'forwardPE': 14.24237, 'priceToBook': 2.6564646, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 36.485, 'beta': 1.043, 'marketCap': 32010450944, 'sector': 'Financial Services'}
# {'ticker': 'SYF', 'trailingPE': 9.610959, 'forwardPE': 10.843896, 'priceToBook': 1.7383118, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.428, 'marketCap': 26706896896, 'sector': 'Financial Services'}
# {'ticker': 'HBAN', 'trailingPE': 13.400001, 'forwardPE': 13.0, 'priceToBook': 1.3758787, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.945, 'marketCap': 25377630208, 'sector': 'Financial Services'}
# {'ticker': 'NTRS', 'trailingPE': 11.858076, 'forwardPE': 16.623037, 'priceToBook': 2.0599494, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.235, 'marketCap': 24706453504, 'sector': 'Financial Services'}
# {'ticker': 'CBOE', 'trailingPE': 30.414154, 'forwardPE': 25.278866, 'priceToBook': 5.4593363, 'pegRatio': None, 'enterpriseToEbitda': 18.159, 'debtToEquity': 36.019, 'beta': 0.428, 'marketCap': 24299698176, 'sector': 'Financial Services'}
# {'ticker': 'CPAY', 'trailingPE': 23.241404, 'forwardPE': 14.931921, 'priceToBook': 6.757601, 'pegRatio': None, 'enterpriseToEbitda': 14.035, 'debtToEquity': 235.922, 'beta': 0.964, 'marketCap': 23346708480, 'sector': 'Technology'}
# {'ticker': 'CINF', 'trailingPE': 15.99891, 'forwardPE': 20.015007, 'priceToBook': 1.6715851, 'pegRatio': None, 'enterpriseToEbitda': 11.68, 'debtToEquity': 6.4, 'beta': 0.786, 'marketCap': 22931361792, 'sector': 'Financial Services'}
# {'ticker': 'RF', 'trailingPE': 11.898551, 'forwardPE': 10.89823, 'priceToBook': 1.3168305, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.978, 'marketCap': 22140645376, 'sector': 'Financial Services'}
# {'ticker': 'TROW', 'trailingPE': 11.515323, 'forwardPE': 10.850266, 'priceToBook': 2.1575007, 'pegRatio': None, 'enterpriseToEbitda': 7.087, 'debtToEquity': 4.48, 'beta': 1.513, 'marketCap': 22351056896, 'sector': 'Financial Services'}
# {'ticker': 'WRB', 'trailingPE': 16.183294, 'forwardPE': 16.034483, 'priceToBook': 2.968085, 'pegRatio': None, 'enterpriseToEbitda': 11.832, 'debtToEquity': 34.344, 'beta': 0.432, 'marketCap': 26460080128, 'sector': 'Financial Services'}
# {'ticker': 'CFG', 'trailingPE': 15.041269, 'forwardPE': 12.242895, 'priceToBook': 0.9113817, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.074, 'marketCap': 20546289664, 'sector': 'Financial Services'}
# {'ticker': 'GPN', 'trailingPE': 13.050162, 'forwardPE': 6.3007812, 'priceToBook': 0.88943046, 'pegRatio': None, 'enterpriseToEbitda': 7.763, 'debtToEquity': 73.574, 'beta': 0.936, 'marketCap': 19668922368, 'sector': 'Industrials'}
# {'ticker': 'KEY', 'trailingPE': None, 'forwardPE': 11.833333, 'priceToBook': 1.2438514, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.074, 'marketCap': 20231051264, 'sector': 'Financial Services'}
# {'ticker': 'FDS', 'trailingPE': 32.28623, 'forwardPE': 23.972698, 'priceToBook': 7.8764906, 'pegRatio': None, 'enterpriseToEbitda': 21.362, 'debtToEquity': 75.191, 'beta': 0.852, 'marketCap': 16930263040, 'sector': 'Financial Services'}
# {'ticker': 'PFG', 'trailingPE': 17.314775, 'forwardPE': 9.580569, 'priceToBook': 1.6217734, 'pegRatio': None, 'enterpriseToEbitda': 10.821, 'debtToEquity': 39.589, 'beta': 0.996, 'marketCap': 18128084992, 'sector': 'Financial Services'}
# {'ticker': 'L', 'trailingPE': 14.9131155, 'forwardPE': 31.368965, 'priceToBook': 1.1130825, 'pegRatio': None, 'enterpriseToEbitda': 8.446, 'debtToEquity': 49.606, 'beta': 0.706, 'marketCap': 19076134912, 'sector': 'Financial Services'}
# {'ticker': 'EG', 'trailingPE': 17.181314, 'forwardPE': 5.117948, 'priceToBook': 1.0224943, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 25.368, 'beta': 0.519, 'marketCap': 14469879808, 'sector': 'Financial Services'}
# {'ticker': 'JKHY', 'trailingPE': 30.571426, 'forwardPE': 28.443037, 'priceToBook': 6.4275756, 'pegRatio': None, 'enterpriseToEbitda': 22.001, 'debtToEquity': 10.972, 'beta': 0.732, 'marketCap': 13089403904, 'sector': 'Technology'}
# {'ticker': 'GL', 'trailingPE': 9.576548, 'forwardPE': 8.6789665, 'priceToBook': 1.797368, 'pegRatio': None, 'enterpriseToEbitda': 8.608, 'debtToEquity': 58.407, 'beta': 0.564, 'marketCap': 9707044864, 'sector': 'Financial Services'}
# {'ticker': 'AIZ', 'trailingPE': 14.859594, 'forwardPE': 10.63058, 'priceToBook': 1.8495505, 'pegRatio': None, 'enterpriseToEbitda': 8.729, 'debtToEquity': 39.809, 'beta': 0.603, 'marketCap': 9658787840, 'sector': 'Financial Services'}
# {'ticker': 'ERIE', 'trailingPE': 29.292517, 'forwardPE': 25.707464, 'priceToBook': 8.713072, 'pegRatio': None, 'enterpriseToEbitda': 22.936, 'debtToEquity': 0.615, 'beta': 0.357, 'marketCap': 18012825600, 'sector': 'Financial Services'}
# {'ticker': 'MKTX', 'trailingPE': 38.003468, 'forwardPE': 26.643988, 'priceToBook': 6.114891, 'pegRatio': None, 'enterpriseToEbitda': 19.142, 'debtToEquity': 5.259, 'beta': 0.842, 'marketCap': 8223372800, 'sector': 'Financial Services'}
# {'ticker': 'BEN', 'trailingPE': 36.086956, 'forwardPE': 9.576923, 'priceToBook': 1.0596647, 'pegRatio': None, 'enterpriseToEbitda': 9.761, 'debtToEquity': 24.117, 'beta': 1.458, 'marketCap': 13085472768, 'sector': 'Financial Services'}
# {'ticker': 'IVZ', 'trailingPE': 13.56, 'forwardPE': 8.968254, 'priceToBook': 0.7097693, 'pegRatio': None, 'enterpriseToEbitda': 9.667, 'debtToEquity': 6.111, 'beta': 1.435, 'marketCap': 7586074624, 'sector': 'Financial Services'}

# %%
def calculate_book(ticker): # Calculate book value per share
    stock = yf.Ticker(ticker)
    info = stock.info

    book_value = info.get("bookValue")



    return book_value

# %%
def get_sector_pb_average(tickers):
    pb_values = []

    for ticker in tickers:
        try:
            info = yf.Ticker(ticker).info
            pb = info.get("priceToBook")
            if pb is not None and pb > 0:
                pb_values.append(pb)
        except Exception as e:
            continue  # Si falla, pasa al siguiente

    if pb_values:
        avg_pb = np.mean(pb_values)
        return round(avg_pb, 2), pb_values
    else:
        return None, []

# %%
avg_pb, pb_list = get_sector_pb_average(tickers)

# Iterar sobre cada empresa y calcular su fair value
for ticker in tickers:
    BVPS = calculate_book(ticker)
    if BVPS is not None and avg_pb is not None:
        fair_value = BVPS * avg_pb
        print(f"{ticker} - Fair Value: {fair_value:.2f}")
# Out:
# BRK-B - Fair Value: 2201781.82
# JPM - Fair Value: 577.11
# V - Fair Value: 95.84
# MA - Fair Value: 35.48
# BAC - Fair Value: 176.11
# WFC - Fair Value: 241.10
# GS - Fair Value: 1797.84
# AXP - Fair Value: 215.43
# MS - Fair Value: 292.37
# SPGI - Fair Value: 526.63
# C - Fair Value: 502.88
# SCHW - Fair Value: 107.46
# BLK - Fair Value: 1499.75
# PGR - Fair Value: 239.14
# COF - Fair Value: 741.84
# BX - Fair Value: 49.95
# MMC - Fair Value: 138.17
# CB - Fair Value: 793.80
# ICE - Fair Value: 235.88
# CME - Fair Value: 363.77
# FI - Fair Value: 225.32
# KKR - Fair Value: 135.82
# AJG - Fair Value: 421.83
# PNC - Fair Value: 619.43
# MCO - Fair Value: 99.52
# AON - Fair Value: 156.87
# COIN - Fair Value: 199.01
# USB - Fair Value: 165.30
# PYPL - Fair Value: 100.13
# BK - Fair Value: 255.64
# APO - Fair Value: 140.66
# TFC - Fair Value: 217.05
# TRV - Fair Value: 602.14
# ALL - Fair Value: 366.27
# AMP - Fair Value: 274.89
# AFL - Fair Value: 234.98
# AIG - Fair Value: 345.51
# MSCI - Fair Value: -59.78
# MET - Fair Value: 197.64
# FIS - Fair Value: 138.61
# PRU - Fair Value: 408.56
# NDAQ - Fair Value: 97.37
# HIG - Fair Value: 280.28
# ACGL - Fair Value: 268.02
# MTB - Fair Value: 791.98
# STT - Fair Value: 387.85
# WTW - Fair Value: 396.77
# BRO - Fair Value: 115.03
# FITB - Fair Value: 132.65
# RJF - Fair Value: 289.07
# SYF - Fair Value: 195.35
# HBAN - Fair Value: 61.28
# NTRS - Fair Value: 298.40
# CBOE - Fair Value: 205.73
# CPAY - Fair Value: 237.21
# CINF - Fair Value: 424.79
# RF - Fair Value: 90.53
# TROW - Fair Value: 227.59
# WRB - Fair Value: 113.74
# CFG - Fair Value: 251.62
# GPN - Fair Value: 438.87
# KEY - Fair Value: 71.83
# FDS - Fair Value: 275.17
# PFG - Fair Value: 241.32
# L - Fair Value: 395.56
# EG - Fair Value: 1610.30
# JKHY - Fair Value: 135.36
# GL - Fair Value: 316.68
# AIZ - Fair Value: 498.51
# ERIE - Fair Value: 191.35
# MKTX - Fair Value: 173.56
# BEN - Fair Value: 113.73
# IVZ - Fair Value: 115.58

# %%
print("P/B promedio del sector:", avg_pb) #Corregir esto, porque es un dato anómalo
# Out:
# P/B promedio del sector: 4.84

# %%
def calculate_current_price(tickers):
    stock = yf.Ticker(ticker)
    info = stock.info
    current_price = info.get("current price")

    return current_price

# %%
def calculate_alpha(tickers):
    alpha = (fair_value - corrent_price) / current_price

# %%
# P/B promedio del sector (puedes calcularlo o meterlo manualmente)
sector_pb_average = 4.82

# Función para calcular fair value y alfa
def analyze_valuation(tickers, sector_pb):
    results = []

    for ticker in tickers:
        try:
            stock = yf.Ticker(ticker)
            info = stock.info

            bvps = info.get("bookValue")
            current_price = info.get("currentPrice")

            # Aseguramos que existan los valores
            if bvps and current_price and bvps > 0 and current_price > 0:
                fair_value = bvps * sector_pb
                alpha = (fair_value - current_price) / current_price

                results.append({
                    "Ticker": ticker,
                    "BVPS": round(bvps, 2),
                    "Precio Actual": round(current_price, 2),
                    "Fair Value": round(fair_value, 2),
                    "Alfa (%)": round(alpha * 100, 2)
                })

        except Exception as e:
            print(f"Error con {ticker}: {e}")
            continue

    return pd.DataFrame(results)

# Ejecutar análisis
df_alphas = analyze_valuation(tickers, sector_pb_average)

# Ver resultados
print(df_alphas)
# Out:
#    Ticker       BVPS  Precio Actual  Fair Value   Alfa (%)
# 0   BRK-B  454913.60         478.91  2192683.55  457748.77
# 1     JPM     119.24         283.16      574.73     102.97
# 2       V      19.80         357.76       95.44     -73.32
# 3      MA       7.33         565.11       35.34     -93.75
# 4     BAC      36.39          46.84      175.38     274.42
# ..    ...        ...            ...         ...        ...
# 67    AIZ     103.00         190.50      496.45     160.60
# 68   ERIE      39.54         344.48      190.56     -44.68
# 69   MKTX      35.86         219.28      172.85     -21.18
# 70    BEN      23.50          24.90      113.26     354.86
# 71    IVZ      23.88          16.95      115.11     579.09
#
# [72 rows x 5 columns]
