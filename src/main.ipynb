# %%
import yfinance as yf
import pandas as pd

# %%
tickers = ["BRK-B", "JPM", "V", "MA", "BAC", "WFC", "GS", "AXP", "MS", "SPGI", "C", "SCHW", "BLK", "PGR", "COF",
"BX", "MMC", "CB", "ICE", "CME", "FI", "KKR", "AJG", "PNC", "MCO", "AON", "COIN", "USB", "PYPL",
"BK", "APO", "TFC", "TRV", "ALL", "AMP", "AFL", "AIG", "MSCI", "MET", "FIS", "PRU", "NDAQ", "HIG",
"ACGL", "MTB", "STT", "WTW", "BRO", "FITB", "RJF", "SYF", "HBAN", "NTRS", "CBOE", "CPAY", "CINF",
"RF", "TROW", "WRB", "CFG", "GPN", "KEY", "FDS", "PFG", "L", "EG", "JKHY", "GL", "AIZ", "ERIE",
"MKTX", "BEN", "IVZ"]

# %%
def CRP(pais): # Defining Country Risk Premium
    return {
        "Abu_Dhabi": 0.0499,
        "Albania": 0.0913,
        "Andorra": 0.0646,
        "Angola": 0.1300,
        "Argentina": 0.2034,
        "Armenia": 0.0913,
        "Aruba": 0.0726,
        "Australia": 0.0433,
        "Austria": 0.0486,
        "Azerbaijan": 0.0767,
        "Bahamas": 0.1034,
        "Bahrain": 0.1167,
        "Bangladesh": 0.1167,
        "Barbados": 0.1300,
        "Belarus": 0.2791,
        "Belgium": 0.0513,
        "Belize": 0.1434,
        "Benin": 0.1034,
        "Bermuda": 0.0546,
        "Bolivia": 0.1768,
        "Bosnia_and_Herzegovina": 0.1300,
        "Botswana": 0.0593,
        "Brazil": 0.0767,
        "Bulgaria": 0.0646,
        "Burkina_Faso": 0.1434,
        "Cambodia": 0.1167,
        "Cameroon": 0.1434,
        "Canada": 0.0433,
        "Cape_Verde": 0.1167,
        "Cayman_Islands": 0.0513,
        "Chile": 0.0546,
        "China": 0.0527,
        "Colombia": 0.0687,
        "Congo_Democratic_Republic_of": 0.1300,
        "Congo_Republic_of": 0.1635,
        "Cook_Islands": 0.1034,
        "Costa_Rica": 0.0913,
        "Côte_d_Ivoire": 0.0835,
        "Croatia": 0.0593,
        "Cuba": 0.2034,
        "Curacao": 0.0726,
        "Cyprus": 0.0593,
        "Czech_Republic": 0.0513,
        "Denmark": 0.0433,
        "Dominican_Republic": 0.0913,
        "Ecuador": 0.1768,
        "Egypt": 0.1434,
        "El_Salvador": 0.1300,
        "Estonia": 0.0527,
        "Ethiopia": 0.1635,
        "Fiji": 0.1034,
        "Finland": 0.0486,
        "France": 0.0513,
        "Gabon": 0.1635,
        "Georgia": 0.0835,
        "Germany": 0.0433,
        "Ghana": 0.1635,
        "Greece": 0.0767,
        "Guatemala": 0.0767,
        "Guernsey": 0.0527,
        "Honduras": 0.1034,
        "Hong_Kong": 0.0513,
        "Hungary": 0.0687,
        "Iceland": 0.0527,
        "India": 0.0726,
        "Indonesia": 0.0687,
        "Iraq": 0.1434,
        "Ireland": 0.0513,
        "Isle_of_Man": 0.0513,
        "Israel": 0.0646,
        "Italy": 0.0726,
        "Jamaica": 0.1034,
        "Japan": 0.0527,
        "Jersey": 0.0499,
        "Jordan": 0.0913,
        "Kazakhstan": 0.0646,
        "Kenya": 0.1434,
        "Korea": 0.0499,
        "Kuwait": 0.0527,
        "Kyrgyzstan": 0.1300,
        "Laos": 0.1768,
        "Latvia": 0.0593,
        "Lebanon": 0.2791,
        "Liechtenstein": 0.0433,
        "Lithuania": 0.0546,
        "Luxembourg": 0.0433,
        "Macao": 0.0513,
        "Macedonia": 0.0913,
        "Malaysia": 0.0593,
        "Maldives": 0.1635,
        "Mali": 0.1635,
        "Malta": 0.0546,
        "Mauritius": 0.0726,
        "Mexico": 0.0687,
        "Moldova": 0.1300,
        "Mongolia": 0.1167,
        "Montenegro": 0.1034,
        "Montserrat": 0.0726,
        "Morocco": 0.0767,
        "Mozambique": 0.1635,
        "Namibia": 0.1034,
        "Nepal": 0.0913,
        "Netherlands": 0.0433,
        "New_Zealand": 0.0433,
        "Nicaragua": 0.1167,
        "Niger": 0.1768,
        "Nigeria": 0.1434,
        "Norway": 0.0433,
        "Oman": 0.0767,
        "Pakistan": 0.1635,
        "Panama": 0.0726,
        "Papua_New_Guinea": 0.1167,
        "Paraguay": 0.0726,
        "Peru": 0.0646,
        "Philippines": 0.0687,
        "Poland": 0.0546,
        "Portugal": 0.0593,
        "Qatar": 0.0499,
        "Ras_Al_Khaimah": 0.0593,
        "Romania": 0.0726,
        "Rwanda": 0.1167,
        "Saudi_Arabia": 0.0513,
        "Senegal": 0.1034,
        "Serbia": 0.0835,
        "Sharjah": 0.0767,
        "Singapore": 0.0433,
        "Slovakia": 0.0593,
        "Slovenia": 0.0593,
        "Solomon_Islands": 0.1434,
        "South_Africa": 0.0835,
        "Spain": 0.0646,
        "Sri_Lanka": 0.2034,
        "St_Maarten": 0.0835,
        "St_Vincent_and_the_Grenadines": 0.1300,
        "Suriname": 0.1434,
        "Swaziland": 0.1167,
        "Sweden": 0.0433,
        "Switzerland": 0.0433,
        "Taiwan": 0.0513,
        "Tajikistan": 0.1300,
        "Tanzania": 0.1034,
        "Thailand": 0.0646,
        "Togo": 0.1300,
        "Trinidad_and_Tobago": 0.0835,
        "Tunisia": 0.1635,
        "Turkey": 0.1034,
        "Turks_and_Caicos_Islands": 0.0646,
        "Uganda": 0.1300,
        "Ukraine": 0.2034,
        "United_Arab_Emirates": 0.0499,
        "United_Kingdom": 0.0513,
        "United_States": 0.0433,
        "Uruguay": 0.0646,
        "Uzbekistan": 0.0913,
        "Venezuela": 0.2791,
        "Vietnam": 0.0835,
        "Zambia": 0.1635
    }.get(pais, 0)

# %%
def risk_free(): # Defining RF de bonos US 10Y
    bond = yf.Ticker("^TNX")  
    return bond.history(period="1d")["Close"].iloc[-1] / 100

# %%
adjusted_risk_free = risk_free() + CRP("Zambia")

# %%
print(valor)
# Out:
# 0.20729000186920166

# %%
def fundamental_ratios(ticker):
    stock = yf.Ticker(ticker)
    info = stock.info

    ratios = {
        "ticker": ticker,
        "trailingPE": info.get("trailingPE"),
        "forwardPE": info.get("forwardPE"),
        "priceToBook": info.get("priceToBook"),
        "pegRatio": info.get("pegRatio"),
        "enterpriseToEbitda": info.get("enterpriseToEbitda"),
        "debtToEquity": info.get("debtToEquity"),
        "beta": info.get("beta"),
        "marketCap": info.get("marketCap"),
        "sector": info.get("sector")
    }

    return ratios

# %%
for ticker in tickers:
    data = fundamental_ratios(ticker)
    print(data)
# Out:
# {'ticker': 'BRK-B', 'trailingPE': 12.730155, 'forwardPE': 23.792963, 'priceToBook': 0.0010502273, 'pegRatio': None, 'enterpriseToEbitda': -1.879, 'debtToEquity': 19.175, 'beta': 0.843, 'marketCap': 1030185418752, 'sector': 'Financial Services'}
# {'ticker': 'JPM', 'trailingPE': 13.953506, 'forwardPE': 16.995937, 'priceToBook': 2.386085, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.084, 'marketCap': 790684434432, 'sector': 'Financial Services'}
# {'ticker': 'V', 'trailingPE': 35.59789, 'forwardPE': 28.005924, 'priceToBook': 17.905912, 'pegRatio': None, 'enterpriseToEbitda': 25.647, 'debtToEquity': 54.594, 'beta': 0.943, 'marketCap': 692623179776, 'sector': 'Financial Services'}
# {'ticker': 'MA', 'trailingPE': 39.308605, 'forwardPE': 34.29304, 'priceToBook': 76.62256, 'pegRatio': None, 'enterpriseToEbitda': 28.991, 'debtToEquity': 280.795, 'beta': 1.052, 'marketCap': 510087790592, 'sector': 'Financial Services'}
# {'ticker': 'BAC', 'trailingPE': 14.0014925, 'forwardPE': 12.815573, 'priceToBook': 1.2890946, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.307, 'marketCap': 353282818048, 'sector': 'Financial Services'}
# {'ticker': 'WFC', 'trailingPE': 14.750864, 'forwardPE': 14.938945, 'priceToBook': 1.6463877, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.155, 'marketCap': 266890936320, 'sector': 'Financial Services'}
# {'ticker': 'GS', 'trailingPE': 16.200047, 'forwardPE': 16.796438, 'priceToBook': 1.8792636, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 593.344, 'beta': 1.314, 'marketCap': 214193422336, 'sector': 'Financial Services'}
# {'ticker': 'AXP', 'trailingPE': 22.238659, 'forwardPE': 21.07672, 'priceToBook': 7.1595783, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 170.351, 'beta': 1.254, 'marketCap': 223263686656, 'sector': 'Financial Services'}
# {'ticker': 'MS', 'trailingPE': 16.68427, 'forwardPE': 17.925598, 'priceToBook': 2.353204, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 416.642, 'beta': 1.291, 'marketCap': 228054073344, 'sector': 'Financial Services'}
# {'ticker': 'SPGI', 'trailingPE': 41.345367, 'forwardPE': 31.33492, 'priceToBook': 4.8410487, 'pegRatio': None, 'enterpriseToEbitda': 24.724, 'debtToEquity': 31.875, 'beta': 1.195, 'marketCap': 161542209536, 'sector': 'Financial Services'}
# {'ticker': 'C', 'trailingPE': 13.618484, 'forwardPE': 11.989569, 'priceToBook': 0.829692, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.31, 'marketCap': 161007665152, 'sector': 'Financial Services'}
# {'ticker': 'SCHW', 'trailingPE': 28.05303, 'forwardPE': 24.361841, 'priceToBook': 4.1694818, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 110.198, 'beta': 0.933, 'marketCap': 168205991936, 'sector': 'Financial Services'}
# {'ticker': 'BLK', 'trailingPE': 26.265486, 'forwardPE': 22.023422, 'priceToBook': 3.4897456, 'pegRatio': None, 'enterpriseToEbitda': 20.33, 'debtToEquity': 28.41, 'beta': 1.423, 'marketCap': 167529234432, 'sector': 'Financial Services'}
# {'ticker': 'PGR', 'trailingPE': 17.020243, 'forwardPE': 18.278261, 'priceToBook': 5.1050396, 'pegRatio': None, 'enterpriseToEbitda': 13.873, 'debtToEquity': 23.81, 'beta': 0.4, 'marketCap': 147869138944, 'sector': 'Financial Services'}
# {'ticker': 'COF', 'trailingPE': 18.487698, 'forwardPE': 14.048761, 'priceToBook': 1.4353802, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.132, 'marketCap': 140722012160, 'sector': 'Financial Services'}
# {'ticker': 'BX', 'trailingPE': 47.507576, 'forwardPE': 26.89108, 'priceToBook': 15.191376, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 73.101, 'beta': 1.641, 'marketCap': 190204116992, 'sector': 'Financial Services'}
# {'ticker': 'MMC', 'trailingPE': 26.154789, 'forwardPE': 22.576881, 'priceToBook': 7.457615, 'pegRatio': None, 'enterpriseToEbitda': 17.356, 'debtToEquity': 157.128, 'beta': 0.827, 'marketCap': 104901787648, 'sector': 'Financial Services'}
# {'ticker': 'CB', 'trailingPE': 13.484112, 'forwardPE': 11.862135, 'priceToBook': 1.7076302, 'pegRatio': None, 'enterpriseToEbitda': 12.5, 'debtToEquity': 29.874, 'beta': 0.555, 'marketCap': 112235487232, 'sector': 'Financial Services'}
# {'ticker': 'ICE', 'trailingPE': 37.459625, 'forwardPE': 26.844213, 'priceToBook': 3.7125268, 'pegRatio': None, 'enterpriseToEbitda': 21.578, 'debtToEquity': 73.534, 'beta': 1.129, 'marketCap': 103786143744, 'sector': 'Financial Services'}
# {'ticker': 'CME', 'trailingPE': 27.628141, 'forwardPE': 26.509161, 'priceToBook': 3.6575794, 'pegRatio': None, 'enterpriseToEbitda': 22.991, 'debtToEquity': 14.045, 'beta': 0.476, 'marketCap': 99062685696, 'sector': 'Financial Services'}
# {'ticker': 'FI', 'trailingPE': 30.053005, 'forwardPE': 16.692837, 'priceToBook': 3.6538215, 'pegRatio': None, 'enterpriseToEbitda': 13.476, 'debtToEquity': 107.142, 'beta': 0.911, 'marketCap': 94309220352, 'sector': 'Technology'}
# {'ticker': 'KKR', 'trailingPE': 59.85345, 'forwardPE': 22.87644, 'priceToBook': 4.9481525, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 74.627, 'beta': 1.884, 'marketCap': 128474660864, 'sector': 'Financial Services'}
# {'ticker': 'AJG', 'trailingPE': 48.653316, 'forwardPE': 27.992908, 'priceToBook': 3.6230123, 'pegRatio': None, 'enterpriseToEbitda': 21.163, 'debtToEquity': 60.048, 'beta': 0.75, 'marketCap': 80851296256, 'sector': 'Financial Services'}
# {'ticker': 'PNC', 'trailingPE': 13.997882, 'forwardPE': 13.205196, 'priceToBook': 1.5487335, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.069, 'marketCap': 78405337088, 'sector': 'Financial Services'}
# {'ticker': 'MCO', 'trailingPE': 43.16062, 'forwardPE': 37.522522, 'priceToBook': 24.305792, 'pegRatio': None, 'enterpriseToEbitda': 28.759, 'debtToEquity': 188.388, 'beta': 1.384, 'marketCap': 89933012992, 'sector': 'Financial Services'}
# {'ticker': 'AON', 'trailingPE': 30.733995, 'forwardPE': 20.43042, 'priceToBook': 10.961865, 'pegRatio': None, 'enterpriseToEbitda': 17.973, 'debtToEquity': 254.468, 'beta': 0.864, 'marketCap': 76720242688, 'sector': 'Financial Services'}
# {'ticker': 'COIN', 'trailingPE': 67.75095, 'forwardPE': 100.96221, 'priceToBook': 8.765871, 'pegRatio': None, 'enterpriseToEbitda': 108.587, 'debtToEquity': 43.892, 'beta': 3.62, 'marketCap': 91804614656, 'sector': 'Financial Services'}
# {'ticker': 'USB', 'trailingPE': 11.752054, 'forwardPE': 10.964965, 'priceToBook': 1.3901649, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.017, 'marketCap': 73972613120, 'sector': 'Financial Services'}
# {'ticker': 'PYPL', 'trailingPE': 16.72809, 'forwardPE': 15.222905, 'priceToBook': 3.5982213, 'pegRatio': None, 'enterpriseToEbitda': 11.683, 'debtToEquity': 66.041, 'beta': 1.449, 'marketCap': 72395358208, 'sector': 'Financial Services'}
# {'ticker': 'BK', 'trailingPE': 15.261012, 'forwardPE': 14.326187, 'priceToBook': 1.7711766, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.075, 'marketCap': 66928852992, 'sector': 'Financial Services'}
# {'ticker': 'APO', 'trailingPE': 25.43979, 'forwardPE': 17.18986, 'priceToBook': 5.015828, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 90.49, 'beta': 1.571, 'marketCap': 83306684416, 'sector': 'Financial Services'}
# {'ticker': 'TFC', 'trailingPE': None, 'forwardPE': 11.488607, 'priceToBook': 1.0119075, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.815, 'marketCap': 59426926592, 'sector': 'Financial Services'}
# {'ticker': 'TRV', 'trailingPE': 13.96269, 'forwardPE': 12.063766, 'priceToBook': 2.0605826, 'pegRatio': None, 'enterpriseToEbitda': 9.961, 'debtToEquity': 28.495, 'beta': 0.537, 'marketCap': 58082095104, 'sector': 'Financial Services'}
# {'ticker': 'ALL', 'trailingPE': 13.239071, 'forwardPE': 10.184971, 'priceToBook': 2.5612156, 'pegRatio': None, 'enterpriseToEbitda': 9.272, 'debtToEquity': 36.672, 'beta': 0.345, 'marketCap': 51327025152, 'sector': 'Financial Services'}
# {'ticker': 'AMP', 'trailingPE': 18.390331, 'forwardPE': 14.010548, 'priceToBook': 9.529492, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 74.235, 'beta': 1.227, 'marketCap': 51537145856, 'sector': 'Financial Services'}
# {'ticker': 'AFL', 'trailingPE': 15.960342, 'forwardPE': 14.31311, 'priceToBook': 2.1138003, 'pegRatio': None, 'enterpriseToEbitda': 13.108, 'debtToEquity': 42.513, 'beta': 0.807, 'marketCap': 55483691008, 'sector': 'Financial Services'}
# {'ticker': 'AIG', 'trailingPE': 20.32317, 'forwardPE': 12.418033, 'priceToBook': 1.1672456, 'pegRatio': None, 'enterpriseToEbitda': 5.978, 'debtToEquity': 21.112, 'beta': 0.658, 'marketCap': 48022695936, 'sector': 'Financial Services'}
# {'ticker': 'MSCI', 'trailingPE': 40.10055, 'forwardPE': 34.170185, 'priceToBook': -47.138924, 'pegRatio': None, 'enterpriseToEbitda': 28.942, 'debtToEquity': None, 'beta': 1.326, 'marketCap': 45050331136, 'sector': 'Financial Services'}
# {'ticker': 'MET', 'trailingPE': 12.933824, 'forwardPE': 8.168731, 'priceToBook': 1.9384581, 'pegRatio': None, 'enterpriseToEbitda': 9.546, 'debtToEquity': 172.754, 'beta': 0.839, 'marketCap': 53136592896, 'sector': 'Financial Services'}
# {'ticker': 'FIS', 'trailingPE': 50.761143, 'forwardPE': 13.957092, 'priceToBook': 2.7827437, 'pegRatio': None, 'enterpriseToEbitda': 20.014, 'debtToEquity': 80.216, 'beta': 1.077, 'marketCap': 41871355904, 'sector': 'Technology'}
# {'ticker': 'PRU', 'trailingPE': 16.935331, 'forwardPE': 7.3090544, 'priceToBook': 1.2719455, 'pegRatio': None, 'enterpriseToEbitda': 17.729, 'debtToEquity': 148.073, 'beta': 1.047, 'marketCap': 38009733120, 'sector': 'Financial Services'}
# {'ticker': 'NDAQ', 'trailingPE': 40.443436, 'forwardPE': 28.464966, 'priceToBook': 4.443008, 'pegRatio': None, 'enterpriseToEbitda': 22.082, 'debtToEquity': 84.587, 'beta': 1.013, 'marketCap': 51315019776, 'sector': 'Financial Services'}
# {'ticker': 'HIG', 'trailingPE': 12.202394, 'forwardPE': 10.541775, 'priceToBook': 2.1134884, 'pegRatio': None, 'enterpriseToEbitda': 8.965, 'debtToEquity': 25.92, 'beta': 0.706, 'marketCap': 34771365888, 'sector': 'Financial Services'}
# {'ticker': 'ACGL', 'trailingPE': 9.2153845, 'forwardPE': 9.939159, 'priceToBook': 1.6225147, 'pegRatio': None, 'enterpriseToEbitda': 7.576, 'debtToEquity': 12.662, 'beta': 0.516, 'marketCap': 33671737344, 'sector': 'Financial Services'}
# {'ticker': 'MTB', 'trailingPE': 13.442437, 'forwardPE': 12.335995, 'priceToBook': 1.2273271, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.61, 'marketCap': 32236429312, 'sector': 'Financial Services'}
# {'ticker': 'STT', 'trailingPE': 12.310811, 'forwardPE': 11.704496, 'priceToBook': 1.3641979, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.463, 'marketCap': 31176097792, 'sector': 'Financial Services'}
# {'ticker': 'WTW', 'trailingPE': None, 'forwardPE': 16.92869, 'priceToBook': 3.735682, 'pegRatio': None, 'enterpriseToEbitda': 13.639, 'debtToEquity': 72.169, 'beta': 0.706, 'marketCap': 30363633664, 'sector': 'Financial Services'}
# {'ticker': 'BRO', 'trailingPE': 30.061281, 'forwardPE': 26.386307, 'priceToBook': 4.5407495, 'pegRatio': None, 'enterpriseToEbitda': 21.095, 'debtToEquity': 59.026, 'beta': 0.839, 'marketCap': 35593850880, 'sector': 'Financial Services'}
# {'ticker': 'FITB', 'trailingPE': 13.788889, 'forwardPE': 11.9, 'priceToBook': 1.584872, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.918, 'marketCap': 28992514048, 'sector': 'Financial Services'}
# {'ticker': 'RJF', 'trailingPE': 15.313102, 'forwardPE': 14.268401, 'priceToBook': 2.66132, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 36.485, 'beta': 1.043, 'marketCap': 32068958208, 'sector': 'Financial Services'}
# {'ticker': 'SYF', 'trailingPE': 9.58767, 'forwardPE': 10.81762, 'priceToBook': 1.7340997, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.428, 'marketCap': 26642182144, 'sector': 'Financial Services'}
# {'ticker': 'HBAN', 'trailingPE': 13.458847, 'forwardPE': 13.057089, 'priceToBook': 1.3819208, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.945, 'marketCap': 25489076224, 'sector': 'Financial Services'}
# {'ticker': 'NTRS', 'trailingPE': 11.847806, 'forwardPE': 16.608639, 'priceToBook': 2.058165, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.235, 'marketCap': 24685053952, 'sector': 'Financial Services'}
# {'ticker': 'CBOE', 'trailingPE': 30.566185, 'forwardPE': 25.405228, 'priceToBook': 5.4866257, 'pegRatio': None, 'enterpriseToEbitda': 18.159, 'debtToEquity': 36.019, 'beta': 0.428, 'marketCap': 24421165056, 'sector': 'Financial Services'}
# {'ticker': 'CPAY', 'trailingPE': 23.162807, 'forwardPE': 14.881425, 'priceToBook': 6.7347484, 'pegRatio': None, 'enterpriseToEbitda': 14.035, 'debtToEquity': 235.922, 'beta': 0.964, 'marketCap': 23267756032, 'sector': 'Technology'}
# {'ticker': 'CINF', 'trailingPE': 15.994547, 'forwardPE': 20.00955, 'priceToBook': 1.6711292, 'pegRatio': None, 'enterpriseToEbitda': 11.68, 'debtToEquity': 6.4, 'beta': 0.786, 'marketCap': 22925107200, 'sector': 'Financial Services'}
# {'ticker': 'RF', 'trailingPE': 11.963768, 'forwardPE': 10.957964, 'priceToBook': 1.3240483, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.978, 'marketCap': 22261999616, 'sector': 'Financial Services'}
# {'ticker': 'TROW', 'trailingPE': 11.432463, 'forwardPE': 10.772192, 'priceToBook': 2.141976, 'pegRatio': None, 'enterpriseToEbitda': 7.087, 'debtToEquity': 4.48, 'beta': 1.513, 'marketCap': 22190227456, 'sector': 'Financial Services'}
# {'ticker': 'WRB', 'trailingPE': 16.338747, 'forwardPE': 16.188505, 'priceToBook': 2.9965956, 'pegRatio': None, 'enterpriseToEbitda': 11.832, 'debtToEquity': 34.344, 'beta': 0.432, 'marketCap': 26714249216, 'sector': 'Financial Services'}
# {'ticker': 'CFG', 'trailingPE': 15.077777, 'forwardPE': 12.27261, 'priceToBook': 0.91359377, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.074, 'marketCap': 20596158464, 'sector': 'Financial Services'}
# {'ticker': 'GPN', 'trailingPE': 12.936085, 'forwardPE': 6.245703, 'priceToBook': 0.8816555, 'pegRatio': None, 'enterpriseToEbitda': 7.763, 'debtToEquity': 73.574, 'beta': 0.936, 'marketCap': 19496986624, 'sector': 'Industrials'}
# {'ticker': 'KEY', 'trailingPE': None, 'forwardPE': 11.884617, 'priceToBook': 1.2492421, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.074, 'marketCap': 20318728192, 'sector': 'Financial Services'}
# {'ticker': 'FDS', 'trailingPE': 32.105408, 'forwardPE': 23.838436, 'priceToBook': 7.832378, 'pegRatio': None, 'enterpriseToEbitda': 21.362, 'debtToEquity': 75.191, 'beta': 0.852, 'marketCap': 16835443712, 'sector': 'Financial Services'}
# {'ticker': 'PFG', 'trailingPE': 17.37045, 'forwardPE': 9.611375, 'priceToBook': 1.6269882, 'pegRatio': None, 'enterpriseToEbitda': 10.821, 'debtToEquity': 39.589, 'beta': 0.996, 'marketCap': 18186375168, 'sector': 'Financial Services'}
# {'ticker': 'L', 'trailingPE': 15.043443, 'forwardPE': 31.643103, 'priceToBook': 1.1228099, 'pegRatio': None, 'enterpriseToEbitda': 8.446, 'debtToEquity': 49.606, 'beta': 0.706, 'marketCap': 19242844160, 'sector': 'Financial Services'}
# {'ticker': 'EG', 'trailingPE': 17.290909, 'forwardPE': 5.1505938, 'priceToBook': 1.0290166, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 25.368, 'beta': 0.519, 'marketCap': 14562179072, 'sector': 'Financial Services'}
# {'ticker': 'JKHY', 'trailingPE': 30.499998, 'forwardPE': 28.376581, 'priceToBook': 6.4125576, 'pegRatio': None, 'enterpriseToEbitda': 22.001, 'debtToEquity': 10.972, 'beta': 0.732, 'marketCap': 13058821120, 'sector': 'Technology'}
# {'ticker': 'GL', 'trailingPE': 9.767916, 'forwardPE': 8.852398, 'priceToBook': 1.8332849, 'pegRatio': None, 'enterpriseToEbitda': 8.608, 'debtToEquity': 58.407, 'beta': 0.564, 'marketCap': 9901020160, 'sector': 'Financial Services'}
# {'ticker': 'AIZ', 'trailingPE': 14.851014, 'forwardPE': 10.624442, 'priceToBook': 1.8484825, 'pegRatio': None, 'enterpriseToEbitda': 8.729, 'debtToEquity': 39.809, 'beta': 0.603, 'marketCap': 9653211136, 'sector': 'Financial Services'}
# {'ticker': 'ERIE', 'trailingPE': 28.982992, 'forwardPE': 25.435822, 'priceToBook': 8.621004, 'pegRatio': None, 'enterpriseToEbitda': 22.936, 'debtToEquity': 0.615, 'beta': 0.357, 'marketCap': 17822488576, 'sector': 'Financial Services'}
# {'ticker': 'MKTX', 'trailingPE': 37.7461, 'forwardPE': 26.463549, 'priceToBook': 6.07348, 'pegRatio': None, 'enterpriseToEbitda': 19.142, 'debtToEquity': 5.259, 'beta': 0.842, 'marketCap': 8167682560, 'sector': 'Financial Services'}
# {'ticker': 'BEN', 'trailingPE': 35.84058, 'forwardPE': 9.5115385, 'priceToBook': 1.05243, 'pegRatio': None, 'enterpriseToEbitda': 9.761, 'debtToEquity': 24.117, 'beta': 1.458, 'marketCap': 12996133888, 'sector': 'Financial Services'}
# {'ticker': 'IVZ', 'trailingPE': 13.5, 'forwardPE': 8.928572, 'priceToBook': 0.7066287, 'pegRatio': None, 'enterpriseToEbitda': 9.667, 'debtToEquity': 6.111, 'beta': 1.435, 'marketCap': 7552507392, 'sector': 'Financial Services'}
