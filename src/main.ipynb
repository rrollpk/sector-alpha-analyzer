# %%
import yfinance as yf
import pandas as pd

# %%
tickers = ["BRK-B", "JPM", "V", "MA", "BAC", "WFC", "GS", "AXP", "MS", "SPGI", "C", "SCHW", "BLK", "PGR", "COF",
"BX", "MMC", "CB", "ICE", "CME", "FI", "KKR", "AJG", "PNC", "MCO", "AON", "COIN", "USB", "PYPL",
"BK", "APO", "TFC", "TRV", "ALL", "AMP", "AFL", "AIG", "MSCI", "MET", "FIS", "PRU", "NDAQ", "HIG",
"ACGL", "MTB", "STT", "WTW", "BRO", "FITB", "RJF", "SYF", "HBAN", "NTRS", "CBOE", "CPAY", "CINF",
"RF", "TROW", "WRB", "CFG", "GPN", "KEY", "FDS", "PFG", "L", "EG", "JKHY", "GL", "AIZ", "ERIE",
"MKTX", "BEN", "IVZ"]

# %%
def CRP(pais): # Defining Country Risk Premium
    return {
        "Abu_Dhabi": 0.0499,
        "Albania": 0.0913,
        "Andorra": 0.0646,
        "Angola": 0.1300,
        "Argentina": 0.2034,
        "Armenia": 0.0913,
        "Aruba": 0.0726,
        "Australia": 0.0433,
        "Austria": 0.0486,
        "Azerbaijan": 0.0767,
        "Bahamas": 0.1034,
        "Bahrain": 0.1167,
        "Bangladesh": 0.1167,
        "Barbados": 0.1300,
        "Belarus": 0.2791,
        "Belgium": 0.0513,
        "Belize": 0.1434,
        "Benin": 0.1034,
        "Bermuda": 0.0546,
        "Bolivia": 0.1768,
        "Bosnia_and_Herzegovina": 0.1300,
        "Botswana": 0.0593,
        "Brazil": 0.0767,
        "Bulgaria": 0.0646,
        "Burkina_Faso": 0.1434,
        "Cambodia": 0.1167,
        "Cameroon": 0.1434,
        "Canada": 0.0433,
        "Cape_Verde": 0.1167,
        "Cayman_Islands": 0.0513,
        "Chile": 0.0546,
        "China": 0.0527,
        "Colombia": 0.0687,
        "Congo_Democratic_Republic_of": 0.1300,
        "Congo_Republic_of": 0.1635,
        "Cook_Islands": 0.1034,
        "Costa_Rica": 0.0913,
        "Côte_d_Ivoire": 0.0835,
        "Croatia": 0.0593,
        "Cuba": 0.2034,
        "Curacao": 0.0726,
        "Cyprus": 0.0593,
        "Czech_Republic": 0.0513,
        "Denmark": 0.0433,
        "Dominican_Republic": 0.0913,
        "Ecuador": 0.1768,
        "Egypt": 0.1434,
        "El_Salvador": 0.1300,
        "Estonia": 0.0527,
        "Ethiopia": 0.1635,
        "Fiji": 0.1034,
        "Finland": 0.0486,
        "France": 0.0513,
        "Gabon": 0.1635,
        "Georgia": 0.0835,
        "Germany": 0.0433,
        "Ghana": 0.1635,
        "Greece": 0.0767,
        "Guatemala": 0.0767,
        "Guernsey": 0.0527,
        "Honduras": 0.1034,
        "Hong_Kong": 0.0513,
        "Hungary": 0.0687,
        "Iceland": 0.0527,
        "India": 0.0726,
        "Indonesia": 0.0687,
        "Iraq": 0.1434,
        "Ireland": 0.0513,
        "Isle_of_Man": 0.0513,
        "Israel": 0.0646,
        "Italy": 0.0726,
        "Jamaica": 0.1034,
        "Japan": 0.0527,
        "Jersey": 0.0499,
        "Jordan": 0.0913,
        "Kazakhstan": 0.0646,
        "Kenya": 0.1434,
        "Korea": 0.0499,
        "Kuwait": 0.0527,
        "Kyrgyzstan": 0.1300,
        "Laos": 0.1768,
        "Latvia": 0.0593,
        "Lebanon": 0.2791,
        "Liechtenstein": 0.0433,
        "Lithuania": 0.0546,
        "Luxembourg": 0.0433,
        "Macao": 0.0513,
        "Macedonia": 0.0913,
        "Malaysia": 0.0593,
        "Maldives": 0.1635,
        "Mali": 0.1635,
        "Malta": 0.0546,
        "Mauritius": 0.0726,
        "Mexico": 0.0687,
        "Moldova": 0.1300,
        "Mongolia": 0.1167,
        "Montenegro": 0.1034,
        "Montserrat": 0.0726,
        "Morocco": 0.0767,
        "Mozambique": 0.1635,
        "Namibia": 0.1034,
        "Nepal": 0.0913,
        "Netherlands": 0.0433,
        "New_Zealand": 0.0433,
        "Nicaragua": 0.1167,
        "Niger": 0.1768,
        "Nigeria": 0.1434,
        "Norway": 0.0433,
        "Oman": 0.0767,
        "Pakistan": 0.1635,
        "Panama": 0.0726,
        "Papua_New_Guinea": 0.1167,
        "Paraguay": 0.0726,
        "Peru": 0.0646,
        "Philippines": 0.0687,
        "Poland": 0.0546,
        "Portugal": 0.0593,
        "Qatar": 0.0499,
        "Ras_Al_Khaimah": 0.0593,
        "Romania": 0.0726,
        "Rwanda": 0.1167,
        "Saudi_Arabia": 0.0513,
        "Senegal": 0.1034,
        "Serbia": 0.0835,
        "Sharjah": 0.0767,
        "Singapore": 0.0433,
        "Slovakia": 0.0593,
        "Slovenia": 0.0593,
        "Solomon_Islands": 0.1434,
        "South_Africa": 0.0835,
        "Spain": 0.0646,
        "Sri_Lanka": 0.2034,
        "St_Maarten": 0.0835,
        "St_Vincent_and_the_Grenadines": 0.1300,
        "Suriname": 0.1434,
        "Swaziland": 0.1167,
        "Sweden": 0.0433,
        "Switzerland": 0.0433,
        "Taiwan": 0.0513,
        "Tajikistan": 0.1300,
        "Tanzania": 0.1034,
        "Thailand": 0.0646,
        "Togo": 0.1300,
        "Trinidad_and_Tobago": 0.0835,
        "Tunisia": 0.1635,
        "Turkey": 0.1034,
        "Turks_and_Caicos_Islands": 0.0646,
        "Uganda": 0.1300,
        "Ukraine": 0.2034,
        "United_Arab_Emirates": 0.0499,
        "United_Kingdom": 0.0513,
        "United_States": 0.0433,
        "Uruguay": 0.0646,
        "Uzbekistan": 0.0913,
        "Venezuela": 0.2791,
        "Vietnam": 0.0835,
        "Zambia": 0.1635
    }.get(pais, 0)

# %%
def risk_free(): # Defining RF de bonos US 10Y
    bond = yf.Ticker("^TNX")  
    return bond.history(period="1d")["Close"].iloc[-1] / 100

# %%
adjusted_risk_free = risk_free() + CRP("Zambia")

# %%
print(adjusted_risk_free)
# Out:
# 0.2070599994659424

# %%
def fundamental_ratios(ticker):
    stock = yf.Ticker(ticker)
    info = stock.info

    ratios = {
        "ticker": ticker,
        "trailingPE": info.get("trailingPE"),
        "forwardPE": info.get("forwardPE"),
        "priceToBook": info.get("priceToBook"),
        "pegRatio": info.get("pegRatio"),
        "enterpriseToEbitda": info.get("enterpriseToEbitda"),
        "debtToEquity": info.get("debtToEquity"),
        "beta": info.get("beta"),
        "marketCap": info.get("marketCap"),
        "sector": info.get("sector")
    }

    return ratios

# %%
for ticker in tickers:
    ratios_tickers = fundamental_ratios(ticker)
    print(ratios_tickers)
# Out:
# {'ticker': 'BRK-B', 'trailingPE': 12.736478, 'forwardPE': 23.804781, 'priceToBook': 0.001050749, 'pegRatio': None, 'enterpriseToEbitda': -1.879, 'debtToEquity': 19.175, 'beta': 0.843, 'marketCap': 1030697123840, 'sector': 'Financial Services'}
# {'ticker': 'JPM', 'trailingPE': 13.905346, 'forwardPE': 16.937277, 'priceToBook': 2.3778493, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.084, 'marketCap': 787955384320, 'sector': 'Financial Services'}
# {'ticker': 'V', 'trailingPE': 35.721386, 'forwardPE': 28.10308, 'priceToBook': 17.96803, 'pegRatio': None, 'enterpriseToEbitda': 25.647, 'debtToEquity': 54.594, 'beta': 0.943, 'marketCap': 695025991680, 'sector': 'Financial Services'}
# {'ticker': 'MA', 'trailingPE': 39.40168, 'forwardPE': 34.374237, 'priceToBook': 76.803986, 'pegRatio': None, 'enterpriseToEbitda': 28.991, 'debtToEquity': 280.795, 'beta': 1.052, 'marketCap': 511295553536, 'sector': 'Financial Services'}
# {'ticker': 'BAC', 'trailingPE': 14.037314, 'forwardPE': 12.848361, 'priceToBook': 1.2923926, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.307, 'marketCap': 354186657792, 'sector': 'Financial Services'}
# {'ticker': 'WFC', 'trailingPE': 14.735612, 'forwardPE': 14.923498, 'priceToBook': 1.6446854, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.155, 'marketCap': 266614980608, 'sector': 'Financial Services'}
# {'ticker': 'GS', 'trailingPE': 16.220818, 'forwardPE': 16.817974, 'priceToBook': 1.8816731, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 593.344, 'beta': 1.314, 'marketCap': 214468050944, 'sector': 'Financial Services'}
# {'ticker': 'AXP', 'trailingPE': 22.292395, 'forwardPE': 21.127647, 'priceToBook': 7.1768775, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 170.351, 'beta': 1.254, 'marketCap': 223803162624, 'sector': 'Financial Services'}
# {'ticker': 'MS', 'trailingPE': 16.640844, 'forwardPE': 17.87894, 'priceToBook': 2.3470788, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 416.642, 'beta': 1.291, 'marketCap': 227460481024, 'sector': 'Financial Services'}
# {'ticker': 'SPGI', 'trailingPE': 41.5259, 'forwardPE': 31.471743, 'priceToBook': 4.862187, 'pegRatio': None, 'enterpriseToEbitda': 24.724, 'debtToEquity': 31.875, 'beta': 1.195, 'marketCap': 162247573504, 'sector': 'Financial Services'}
# {'ticker': 'C', 'trailingPE': 13.591075, 'forwardPE': 11.965438, 'priceToBook': 0.8280221, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.31, 'marketCap': 160683622400, 'sector': 'Financial Services'}
# {'ticker': 'SCHW', 'trailingPE': 28.03788, 'forwardPE': 24.348684, 'priceToBook': 4.1672297, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 110.198, 'beta': 0.933, 'marketCap': 168115142656, 'sector': 'Financial Services'}
# {'ticker': 'BLK', 'trailingPE': 26.278116, 'forwardPE': 22.034014, 'priceToBook': 3.4914238, 'pegRatio': None, 'enterpriseToEbitda': 20.33, 'debtToEquity': 28.41, 'beta': 1.423, 'marketCap': 167609794560, 'sector': 'Financial Services'}
# {'ticker': 'PGR', 'trailingPE': 16.934547, 'forwardPE': 18.186232, 'priceToBook': 5.079336, 'pegRatio': None, 'enterpriseToEbitda': 13.873, 'debtToEquity': 23.81, 'beta': 0.4, 'marketCap': 147124633600, 'sector': 'Financial Services'}
# {'ticker': 'COF', 'trailingPE': 18.419748, 'forwardPE': 13.997127, 'priceToBook': 1.4301046, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.132, 'marketCap': 140204802048, 'sector': 'Financial Services'}
# {'ticker': 'BX', 'trailingPE': 47.97879, 'forwardPE': 27.157804, 'priceToBook': 15.342055, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 73.101, 'beta': 1.641, 'marketCap': 192090701824, 'sector': 'Financial Services'}
# {'ticker': 'MMC', 'trailingPE': 26.255527, 'forwardPE': 22.663837, 'priceToBook': 7.4863386, 'pegRatio': None, 'enterpriseToEbitda': 17.356, 'debtToEquity': 157.128, 'beta': 0.827, 'marketCap': 105305825280, 'sector': 'Financial Services'}
# {'ticker': 'CB', 'trailingPE': 13.455464, 'forwardPE': 11.836933, 'priceToBook': 1.7040023, 'pegRatio': None, 'enterpriseToEbitda': 12.5, 'debtToEquity': 29.874, 'beta': 0.555, 'marketCap': 111997042688, 'sector': 'Financial Services'}
# {'ticker': 'ICE', 'trailingPE': 37.52795, 'forwardPE': 26.893175, 'priceToBook': 3.7192981, 'pegRatio': None, 'enterpriseToEbitda': 21.578, 'debtToEquity': 73.534, 'beta': 1.129, 'marketCap': 103975444480, 'sector': 'Financial Services'}
# {'ticker': 'CME', 'trailingPE': 27.59598, 'forwardPE': 26.478302, 'priceToBook': 3.6533215, 'pegRatio': None, 'enterpriseToEbitda': 22.991, 'debtToEquity': 14.045, 'beta': 0.476, 'marketCap': 98947375104, 'sector': 'Financial Services'}
# {'ticker': 'FI', 'trailingPE': 30.217316, 'forwardPE': 16.784103, 'priceToBook': 3.673798, 'pegRatio': None, 'enterpriseToEbitda': 13.476, 'debtToEquity': 107.142, 'beta': 0.911, 'marketCap': 94824841216, 'sector': 'Technology'}
# {'ticker': 'KKR', 'trailingPE': 60.10754, 'forwardPE': 22.973557, 'priceToBook': 4.9691586, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 74.627, 'beta': 1.884, 'marketCap': 129020059648, 'sector': 'Financial Services'}
# {'ticker': 'AJG', 'trailingPE': 48.51156, 'forwardPE': 27.911348, 'priceToBook': 3.612456, 'pegRatio': None, 'enterpriseToEbitda': 21.163, 'debtToEquity': 60.048, 'beta': 0.75, 'marketCap': 80615727104, 'sector': 'Financial Services'}
# {'ticker': 'PNC', 'trailingPE': 13.952684, 'forwardPE': 13.162559, 'priceToBook': 1.5437328, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.069, 'marketCap': 78152179712, 'sector': 'Financial Services'}
# {'ticker': 'MCO', 'trailingPE': 43.2582, 'forwardPE': 37.607357, 'priceToBook': 24.360744, 'pegRatio': None, 'enterpriseToEbitda': 28.759, 'debtToEquity': 188.388, 'beta': 1.384, 'marketCap': 90136338432, 'sector': 'Financial Services'}
# {'ticker': 'AON', 'trailingPE': 30.825258, 'forwardPE': 20.491087, 'priceToBook': 10.994415, 'pegRatio': None, 'enterpriseToEbitda': 17.973, 'debtToEquity': 254.468, 'beta': 0.864, 'marketCap': 76948062208, 'sector': 'Financial Services'}
# {'ticker': 'COIN', 'trailingPE': 68.55075, 'forwardPE': 102.15407, 'priceToBook': 8.869351, 'pegRatio': None, 'enterpriseToEbitda': 108.587, 'debtToEquity': 43.892, 'beta': 3.62, 'marketCap': 92888367104, 'sector': 'Financial Services'}
# {'ticker': 'USB', 'trailingPE': 11.731436, 'forwardPE': 10.945727, 'priceToBook': 1.3877258, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.017, 'marketCap': 73842827264, 'sector': 'Financial Services'}
# {'ticker': 'PYPL', 'trailingPE': 16.84045, 'forwardPE': 15.325154, 'priceToBook': 3.62239, 'pegRatio': None, 'enterpriseToEbitda': 11.683, 'debtToEquity': 66.041, 'beta': 1.449, 'marketCap': 72881627136, 'sector': 'Financial Services'}
# {'ticker': 'BK', 'trailingPE': 15.212071, 'forwardPE': 14.280245, 'priceToBook': 1.7654966, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.075, 'marketCap': 66714218496, 'sector': 'Financial Services'}
# {'ticker': 'APO', 'trailingPE': 25.616928, 'forwardPE': 17.309553, 'priceToBook': 5.0507536, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 90.49, 'beta': 1.571, 'marketCap': 83886751744, 'sector': 'Financial Services'}
# {'ticker': 'TFC', 'trailingPE': None, 'forwardPE': 11.467088, 'priceToBook': 1.010012, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.815, 'marketCap': 59315609600, 'sector': 'Financial Services'}
# {'ticker': 'TRV', 'trailingPE': 13.90768, 'forwardPE': 12.016235, 'priceToBook': 2.052464, 'pegRatio': None, 'enterpriseToEbitda': 9.961, 'debtToEquity': 28.495, 'beta': 0.537, 'marketCap': 57853259776, 'sector': 'Financial Services'}
# {'ticker': 'ALL', 'trailingPE': 13.216188, 'forwardPE': 10.167367, 'priceToBook': 2.556789, 'pegRatio': None, 'enterpriseToEbitda': 9.272, 'debtToEquity': 36.672, 'beta': 0.345, 'marketCap': 51238309888, 'sector': 'Financial Services'}
# {'ticker': 'AMP', 'trailingPE': 18.32076, 'forwardPE': 13.957545, 'priceToBook': 9.493442, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 74.235, 'beta': 1.227, 'marketCap': 51342176256, 'sector': 'Financial Services'}
# {'ticker': 'AFL', 'trailingPE': 15.864697, 'forwardPE': 14.227336, 'priceToBook': 2.1011329, 'pegRatio': None, 'enterpriseToEbitda': 13.108, 'debtToEquity': 42.513, 'beta': 0.807, 'marketCap': 55151198208, 'sector': 'Financial Services'}
# {'ticker': 'AIG', 'trailingPE': 20.315853, 'forwardPE': 12.413562, 'priceToBook': 1.1668254, 'pegRatio': None, 'enterpriseToEbitda': 5.978, 'debtToEquity': 21.112, 'beta': 0.658, 'marketCap': 48005406720, 'sector': 'Financial Services'}
# {'ticker': 'MSCI', 'trailingPE': 40.13481, 'forwardPE': 34.199383, 'priceToBook': -47.179203, 'pegRatio': None, 'enterpriseToEbitda': 28.942, 'debtToEquity': None, 'beta': 1.326, 'marketCap': 45088825344, 'sector': 'Financial Services'}
# {'ticker': 'MET', 'trailingPE': 12.854575, 'forwardPE': 8.118679, 'priceToBook': 1.9265808, 'pegRatio': None, 'enterpriseToEbitda': 9.546, 'debtToEquity': 172.754, 'beta': 0.839, 'marketCap': 52811010048, 'sector': 'Financial Services'}
# {'ticker': 'FIS', 'trailingPE': 50.802547, 'forwardPE': 13.968476, 'priceToBook': 2.7850134, 'pegRatio': None, 'enterpriseToEbitda': 20.014, 'debtToEquity': 80.216, 'beta': 1.077, 'marketCap': 41905508352, 'sector': 'Technology'}
# {'ticker': 'PRU', 'trailingPE': 16.847002, 'forwardPE': 7.2709327, 'priceToBook': 1.2653114, 'pegRatio': None, 'enterpriseToEbitda': 17.729, 'debtToEquity': 148.073, 'beta': 1.047, 'marketCap': 37811486720, 'sector': 'Financial Services'}
# {'ticker': 'NDAQ', 'trailingPE': 40.506786, 'forwardPE': 28.509552, 'priceToBook': 4.4499674, 'pegRatio': None, 'enterpriseToEbitda': 22.082, 'debtToEquity': 84.587, 'beta': 1.013, 'marketCap': 51395399680, 'sector': 'Financial Services'}
# {'ticker': 'HIG', 'trailingPE': 12.148555, 'forwardPE': 10.495263, 'priceToBook': 2.1041634, 'pegRatio': None, 'enterpriseToEbitda': 8.965, 'debtToEquity': 25.92, 'beta': 0.706, 'marketCap': 34617950208, 'sector': 'Financial Services'}
# {'ticker': 'ACGL', 'trailingPE': 9.087179, 'forwardPE': 9.800885, 'priceToBook': 1.5999422, 'pegRatio': None, 'enterpriseToEbitda': 7.576, 'debtToEquity': 12.662, 'beta': 0.516, 'marketCap': 33203292160, 'sector': 'Financial Services'}
# {'ticker': 'MTB', 'trailingPE': 13.398929, 'forwardPE': 12.296068, 'priceToBook': 1.2233548, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.61, 'marketCap': 32132091904, 'sector': 'Financial Services'}
# {'ticker': 'STT', 'trailingPE': 12.320946, 'forwardPE': 11.714133, 'priceToBook': 1.365321, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.463, 'marketCap': 31201765376, 'sector': 'Financial Services'}
# {'ticker': 'WTW', 'trailingPE': None, 'forwardPE': 16.981205, 'priceToBook': 3.7472708, 'pegRatio': None, 'enterpriseToEbitda': 13.639, 'debtToEquity': 72.169, 'beta': 0.706, 'marketCap': 30457827328, 'sector': 'Financial Services'}
# {'ticker': 'BRO', 'trailingPE': 30.008358, 'forwardPE': 26.339853, 'priceToBook': 4.5327554, 'pegRatio': None, 'enterpriseToEbitda': 21.095, 'debtToEquity': 59.026, 'beta': 0.839, 'marketCap': 35531186176, 'sector': 'Financial Services'}
# {'ticker': 'FITB', 'trailingPE': 13.828571, 'forwardPE': 11.934247, 'priceToBook': 1.589433, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.918, 'marketCap': 29075951616, 'sector': 'Financial Services'}
# {'ticker': 'RJF', 'trailingPE': 15.336224, 'forwardPE': 14.289946, 'priceToBook': 2.6653383, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 36.485, 'beta': 1.043, 'marketCap': 32117381120, 'sector': 'Financial Services'}
# {'ticker': 'SYF', 'trailingPE': 9.609589, 'forwardPE': 10.84235, 'priceToBook': 1.738064, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.428, 'marketCap': 26703087616, 'sector': 'Financial Services'}
# {'ticker': 'HBAN', 'trailingPE': 13.446, 'forwardPE': 13.044626, 'priceToBook': 1.3806018, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.945, 'marketCap': 25464745984, 'sector': 'Financial Services'}
# {'ticker': 'NTRS', 'trailingPE': 11.915032, 'forwardPE': 16.70288, 'priceToBook': 2.0698435, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.235, 'marketCap': 24825122816, 'sector': 'Financial Services'}
# {'ticker': 'CBOE', 'trailingPE': 30.401049, 'forwardPE': 25.267973, 'priceToBook': 5.4569836, 'pegRatio': None, 'enterpriseToEbitda': 18.159, 'debtToEquity': 36.019, 'beta': 0.428, 'marketCap': 24289228800, 'sector': 'Financial Services'}
# {'ticker': 'CPAY', 'trailingPE': 23.232983, 'forwardPE': 14.926511, 'priceToBook': 6.755152, 'pegRatio': None, 'enterpriseToEbitda': 14.035, 'debtToEquity': 235.922, 'beta': 0.964, 'marketCap': 23338250240, 'sector': 'Technology'}
# {'ticker': 'CINF', 'trailingPE': 15.94193, 'forwardPE': 19.943724, 'priceToBook': 1.6656318, 'pegRatio': None, 'enterpriseToEbitda': 11.68, 'debtToEquity': 6.4, 'beta': 0.786, 'marketCap': 22849691648, 'sector': 'Financial Services'}
# {'ticker': 'RF', 'trailingPE': 11.954107, 'forwardPE': 10.949116, 'priceToBook': 1.3229791, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 0.978, 'marketCap': 22244022272, 'sector': 'Financial Services'}
# {'ticker': 'TROW', 'trailingPE': 11.488648, 'forwardPE': 10.825133, 'priceToBook': 2.152503, 'pegRatio': None, 'enterpriseToEbitda': 7.087, 'debtToEquity': 4.48, 'beta': 1.513, 'marketCap': 22299283456, 'sector': 'Financial Services'}
# {'ticker': 'WRB', 'trailingPE': 16.26102, 'forwardPE': 16.111494, 'priceToBook': 2.9823403, 'pegRatio': None, 'enterpriseToEbitda': 11.832, 'debtToEquity': 34.344, 'beta': 0.432, 'marketCap': 26587164672, 'sector': 'Financial Services'}
# {'ticker': 'CFG', 'trailingPE': 15.077777, 'forwardPE': 12.27261, 'priceToBook': 0.91359377, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.074, 'marketCap': 20596158464, 'sector': 'Financial Services'}
# {'ticker': 'GPN', 'trailingPE': 13.064725, 'forwardPE': 6.307812, 'priceToBook': 0.890423, 'pegRatio': None, 'enterpriseToEbitda': 7.763, 'debtToEquity': 73.574, 'beta': 0.936, 'marketCap': 19690870784, 'sector': 'Industrials'}
# {'ticker': 'KEY', 'trailingPE': None, 'forwardPE': 11.871796, 'priceToBook': 1.2478944, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': None, 'beta': 1.074, 'marketCap': 20296808448, 'sector': 'Financial Services'}
# {'ticker': 'FDS', 'trailingPE': 32.120403, 'forwardPE': 23.849571, 'priceToBook': 7.836036, 'pegRatio': None, 'enterpriseToEbitda': 21.362, 'debtToEquity': 75.191, 'beta': 0.852, 'marketCap': 16843308032, 'sector': 'Financial Services'}
# {'ticker': 'PFG', 'trailingPE': 17.331905, 'forwardPE': 9.590048, 'priceToBook': 1.6233779, 'pegRatio': None, 'enterpriseToEbitda': 10.821, 'debtToEquity': 39.589, 'beta': 0.996, 'marketCap': 18146021376, 'sector': 'Financial Services'}
# {'ticker': 'L', 'trailingPE': 14.992623, 'forwardPE': 31.536207, 'priceToBook': 1.1190168, 'pegRatio': None, 'enterpriseToEbitda': 8.446, 'debtToEquity': 49.606, 'beta': 0.706, 'marketCap': 19177838592, 'sector': 'Financial Services'}
# {'ticker': 'EG', 'trailingPE': 17.237879, 'forwardPE': 5.1347976, 'priceToBook': 1.0258607, 'pegRatio': None, 'enterpriseToEbitda': None, 'debtToEquity': 25.368, 'beta': 0.519, 'marketCap': 14517518336, 'sector': 'Financial Services'}
# {'ticker': 'JKHY', 'trailingPE': 30.510202, 'forwardPE': 28.386074, 'priceToBook': 6.414703, 'pegRatio': None, 'enterpriseToEbitda': 22.001, 'debtToEquity': 10.972, 'beta': 0.732, 'marketCap': 13063189504, 'sector': 'Technology'}
# {'ticker': 'GL', 'trailingPE': 9.633958, 'forwardPE': 8.730996, 'priceToBook': 1.8081431, 'pegRatio': None, 'enterpriseToEbitda': 8.608, 'debtToEquity': 58.407, 'beta': 0.564, 'marketCap': 9765237760, 'sector': 'Financial Services'}
# {'ticker': 'AIZ', 'trailingPE': 14.839314, 'forwardPE': 10.616072, 'priceToBook': 1.8470262, 'pegRatio': None, 'enterpriseToEbitda': 8.729, 'debtToEquity': 39.809, 'beta': 0.603, 'marketCap': 9645605888, 'sector': 'Financial Services'}
# {'ticker': 'ERIE', 'trailingPE': 29.160713, 'forwardPE': 25.591791, 'priceToBook': 8.673867, 'pegRatio': None, 'enterpriseToEbitda': 22.936, 'debtToEquity': 0.615, 'beta': 0.357, 'marketCap': 17931776000, 'sector': 'Financial Services'}
# {'ticker': 'MKTX', 'trailingPE': 37.81456, 'forwardPE': 26.511545, 'priceToBook': 6.084495, 'pegRatio': None, 'enterpriseToEbitda': 19.142, 'debtToEquity': 5.259, 'beta': 0.842, 'marketCap': 8182496256, 'sector': 'Financial Services'}
# {'ticker': 'BEN', 'trailingPE': 36.036232, 'forwardPE': 9.563462, 'priceToBook': 1.0581752, 'pegRatio': None, 'enterpriseToEbitda': 9.761, 'debtToEquity': 24.117, 'beta': 1.458, 'marketCap': 13067079680, 'sector': 'Financial Services'}
# {'ticker': 'IVZ', 'trailingPE': 13.588, 'forwardPE': 8.986773, 'priceToBook': 0.71123487, 'pegRatio': None, 'enterpriseToEbitda': 9.667, 'debtToEquity': 6.111, 'beta': 1.435, 'marketCap': 7601738752, 'sector': 'Financial Services'}

# %%
def calculate_book(ticker):
        stock = yf.Ticker(ticker)
        info = stock.info
        book_value_per_share = info.get("bookValue")

        return book_value_per_share

# %%
def get_sector_pb_average(tickers):
    pb_values = []

    for ticker in tickers:
        try:
            info = yf.Ticker(ticker).info
            pb = info.get("priceToBook")
            if pb is not None and pb > 0:
                pb_values.append(pb)
        except Exception as e:
            continue  # Si falla, pasa al siguiente

    if pb_values:
        avg_pb = np.mean(pb_values)
        return round(avg_pb, 2), pb_values
    else:
        return None, []

# %%
for ticker in tickers:
     avg_pb, pb_list = get_sector_pb_average(tickers)
     BVPS = calculate_book
     Fair = BVPS / avg_pb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 for ticker in tickers:
# ----> 2      avg_pb, pb_list = get_sector_pb_average(tickers)
#       3      BVPS = calculate_book
#       4      Fair = BVPS / avg_pb
#
# Cell In[41], line 14, in get_sector_pb_average(tickers)
#      11         continue  # Si falla, pasa al siguiente
#      13 if pb_values:
# ---> 14     avg_pb = np.mean(pb_values)
#      15     return round(avg_pb, 2), pb_values
#      16 else:
#
# NameError: name 'np' is not defined
